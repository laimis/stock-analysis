// %%
#r "nuget: Microsoft.DotNet.Cli.Utils"

open Microsoft.DotNet.Cli.Utils

let runDotNetBuild() =
    let result = 
        Command
            .CreateDotNet("build", [])
            .CaptureStdOut()
            .CaptureStdErr()
            .Execute()

    let output = result.StdOut
    let error = result.StdErr
    let exitCode = result.ExitCode

    (output, error, exitCode)

// Usage
let (output, error, exitCode) = runDotNetBuild()

printfn "Exit Code: %d" exitCode
printfn "Output:\n%s" output
printfn "Error:\n%s" error
// Out:
// <div>
//     <div id='dotnet-interactive-this-cell-22808.Microsoft.DotNet.Interactive.Http.HttpPort' style='display: none'>
//         The below script needs to be able to find the current output cell; this is an easy method to get it.
//     </div>
//     <script type='text/javascript'>
// async function probeAddresses(probingAddresses) {
//     function timeout(ms, promise) {
//         return new Promise(function (resolve, reject) {
//             setTimeout(function () {
//                 reject(new Error('timeout'))
//             }, ms)
//             promise.then(resolve, reject)
//         })
//     }
//
//     if (Array.isArray(probingAddresses)) {
//         for (let i = 0; i < probingAddresses.length; i++) {
//
//             let rootUrl = probingAddresses[i];
//
//             if (!rootUrl.endsWith('/')) {
//                 rootUrl = `${rootUrl}/`;
//             }
//
//             try {
//                 let response = await timeout(1000, fetch(`${rootUrl}discovery`, {
//                     method: 'POST',
//                     cache: 'no-cache',
//                     mode: 'cors',
//                     timeout: 1000,
//                     headers: {
//                         'Content-Type': 'text/plain'
//                     },
//                     body: probingAddresses[i]
//                 }));
//
//                 if (response.status == 200) {
//                     return rootUrl;
//                 }
//             }
//             catch (e) { }
//         }
//     }
// }
//
// function loadDotnetInteractiveApi() {
//     probeAddresses(["http://192.168.86.24:2048/", "http://127.0.0.1:2048/"])
//         .then((root) => {
//         // use probing to find host url and api resources
//         // load interactive helpers and language services
//         let dotnetInteractiveRequire = require.config({
//         context: '22808.Microsoft.DotNet.Interactive.Http.HttpPort',
//                 paths:
//             {
//                 'dotnet-interactive': `${root}resources`
//                 }
//         }) || require;
//
//             window.dotnetInteractiveRequire = dotnetInteractiveRequire;
//
//             window.configureRequireFromExtension = function(extensionName, extensionCacheBuster) {
//                 let paths = {};
//                 paths[extensionName] = `${root}extensions/${extensionName}/resources/`;
//
//                 let internalRequire = require.config({
//                     context: extensionCacheBuster,
//                     paths: paths,
//                     urlArgs: `cacheBuster=${extensionCacheBuster}`
//                     }) || require;
//
//                 return internalRequire
//             };
//
//             dotnetInteractiveRequire([
//                     'dotnet-interactive/dotnet-interactive'
//                 ],
//                 function (dotnet) {
//                     dotnet.init(window);
//                 },
//                 function (error) {
//                     console.log(error);
//                 }
//             );
//         })
//         .catch(error => {console.log(error);});
//     }
//
// // ensure `require` is available globally
// if ((typeof(require) !==  typeof(Function)) || (typeof(require.config) !== typeof(Function))) {
//     let require_script = document.createElement('script');
//     require_script.setAttribute('src', 'https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js');
//     require_script.setAttribute('type', 'text/javascript');
//
//
//     require_script.onload = function() {
//         loadDotnetInteractiveApi();
//     };
//
//     document.getElementsByTagName('head')[0].appendChild(require_script);
// }
// else {
//     loadDotnetInteractiveApi();
// }
//
//     </script>
// </div>
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.DotNet.Cli.Utils, 2.0.0</span></li></ul></div></div>
// Exit Code: 0
// Output:
// MSBuild version 17.8.5+b5265ef37 for .NET
//   Determining projects to restore...
//   All projects are up-to-date for restore.
//   core -> D:\programming\stock-analysis\src\core\bin\Debug\net8.0\core.dll
//   core.fs -> D:\programming\stock-analysis\src\core.fs\bin\Debug\net8.0\core.fs.dll
//   secedgar -> D:\programming\stock-analysis\src\infrastructure\secedgar\bin\Debug\net8.0\secedgar.dll
//   stripe -> D:\programming\stock-analysis\src\infrastructure\stripe\bin\Debug\net8.0\stripe.dll
//   twilioclient -> D:\programming\stock-analysis\src\infrastructure\twilioclient\bin\Debug\net8.0\twilioclient.dll
//   storage.shared -> D:\programming\stock-analysis\src\infrastructure\storage.shared\bin\Debug\net8.0\storage.shared.dll
//   timezonesupport -> D:\programming\stock-analysis\src\infrastructure\timezonesupport\bin\Debug\net8.0\timezonesupport.dll
//   csvparser -> D:\programming\stock-analysis\src\infrastructure\csvparser\bin\Debug\net8.0\csvparser.dll
//   securityutils -> D:\programming\stock-analysis\src\infrastructure\securityutils\bin\Debug\net8.0\securityutils.dll
//   coinmarketcap -> D:\programming\stock-analysis\src\infrastructure\coinmarketcap\bin\Debug\net8.0\coinmarketcap.dll
//   sendgridclient -> D:\programming\stock-analysis\src\infrastructure\sendgridclient\bin\Debug\net8.0\sendgridclient.dll
//   storage.memory -> D:\programming\stock-analysis\src\infrastructure\storage.memory\bin\Debug\net8.0\storage.memory.dll
//   schwabclient -> D:\programming\stock-analysis\src\infrastructure\schwabclient\bin\Debug\net8.0\schwabclient.dll
//   storage.postgres -> D:\programming\stock-analysis\src\infrastructure\storage.postgres\bin\Debug\net8.0\storage.postgres.dll
//   web -> D:\programming\stock-analysis\src\web\bin\Debug\net8.0\web.dll
//   studies -> D:\programming\stock-analysis\src\studies\bin\Debug\net8.0\studies.dll
// Build succeeded.
//     0 Warning(s)
//     0 Error(s)
// Time Elapsed 00:00:03.98
//
// Error:

// %%
let buildDir = "./bin/Debug/net8.0" 
let copyDir = "./bin/Debug/notebook"

// Clear existing copy directory
if System.IO.Directory.Exists(copyDir) then 
    System.IO.Directory.Delete(copyDir, true)

let rec copyBuildDir (source : string) (target: string) =
    System.IO.Directory.CreateDirectory(target) |> ignore  
    for file in System.IO.Directory.GetFiles(source) do 
        File.Copy(file, System.IO.Path.Combine(target, System.IO.Path.GetFileName(file)))

    for dir in System.IO.Directory.GetDirectories(source) do
        let newDir = System.IO.Path.Combine(target, System.IO.Path.GetFileName(dir)) 
        copyBuildDir dir newDir

copyBuildDir buildDir copyDir

// %%
#r "./bin/Debug/notebook/studies.dll"
#r "./bin/Debug/notebook/core.fs.dll"

#r "nuget:FSharp.Data"
#r "nuget: Plotly.NET.Interactive"
#r "nuget: MathNet.Numerics"
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>FSharp.Data, 6.4.0</span></li><li><span>MathNet.Numerics, 5.0.0</span></li><li><span>Plotly.NET.Interactive, 5.0.0</span></li></ul></div></div>
// Loading extensions from `C:\Users\laimi\.nuget\packages\plotly.net.interactive\5.0.0\lib\netstandard2.1\Plotly.NET.Interactive.dll`

// %%
// read params from files
let resultsDirectory = @"D:\studies\breakout_study_2024\results_20240621_090304"
let studiesDirectory = @"D:\studies\breakout_study_2024"

//let resultsDirectory = System.IO.File.ReadAllText("results_directory.txt")
//let studiesDirectory = System.IO.File.ReadAllText("study_directory.txt")
let inputFilename    = $"{studiesDirectory}\\signals.csv"

System.Console.WriteLine("Study directory: " + studiesDirectory)
System.Console.WriteLine("Input filename: " + inputFilename)
System.Console.WriteLine("Results directory: " + resultsDirectory)
// Out:
// Study directory: D:\studies\breakout_study_2024
// Input filename: D:\studies\breakout_study_2024\signals.csv
// Results directory: D:\studies\breakout_study_2024\results_20240621_090304

// %%
open FSharp.Data
open Plotly.NET
open core.fs.Stocks

let outputToConsole (message:string) =
    System.Console.WriteLine(message)
        
// functions that deal with outcomes and turn them into summaries, describes them, etc
let columnChart label keys values =
    let column = 
        Chart.Column(values = values, Keys = keys)
        |> Chart.withYAxisStyle (TitleText = label)
    
    column.Display() |> ignore
    
let histogramChart label bins values =
    let chart = 
        Chart.Histogram(
            X = values,
            NBinsX = bins,
            Name = label
        )
    chart.Display() |> ignore

let outputSummary outputFunc includeDistributionChart (summary:studies.Trading.TradeSummary) = 

    // this ensures that the numbers align instead of negative EV taking up more space
    let evPositiveSign =
        match summary.EV with
        | x when x >= 0m -> "+"
        | _ -> ""
    
    let format = "0.00"
    let percentFormat = "00.00%"
    outputFunc $"{evPositiveSign}{summary.EV.ToString(percentFormat)} EV -> {summary.WinPct.ToString(percentFormat)} \t {summary.AvgWin.ToString(percentFormat)} \t {summary.AvgLoss.ToString(percentFormat)} \t {summary.AvgGainLoss.ToString(format)} avg gain/loss \t {summary.TotalGain.ToString(format)} total gain  \t [{summary.NumberOfTrades} trades] \t {summary.StrategyName}"
        
    match includeDistributionChart with
    | true ->
        histogramChart "Gain Distribution" 40 (summary.Gains)
    | false -> ()
    
    
// filter out outcomes that have minimum of trades we are interested in
let minimumTradesPerCategory = 10

let createTradeSummaries outcomes =
    
    let tradesGroupedByStrategy =
        outcomes
        |> Seq.groupBy (fun (t:studies.Trading.TradeOutcome) -> t.Strategy) // all strategies, no filters

    tradesGroupedByStrategy
    |> Seq.map (
        fun (strategy, trades) ->
            let name = $"{strategy}"
            let summary = trades |> studies.Trading.TradeSummary.create name
            match summary.NumberOfTrades with
            | x when x < minimumTradesPerCategory -> None
            | _ -> Some summary
    )
    |> Seq.choose id
    

type OutcomeGrouping =
    | Signal
    | Strategy
    
let describeOutcomes outputFileOption includeEVChart includeDistributionChart tradeSummaries =
    
    let outputContent message =
        match outputFileOption with
        | None -> ()
        | Some outputFile -> System.IO.File.AppendAllText(outputFile, message + System.Environment.NewLine)
        System.Console.WriteLine(message)
        
    let groupedData = tradeSummaries |> Seq.groupBy (fun (o:studies.Trading.TradeSummary) -> o.StrategyName)
    
    groupedData
    |> Seq.iter (
        fun (groupingName,summaries) ->
            
            outputContent $"{groupingName}"
            
            let sortedSummaries = summaries |> Seq.sortByDescending (fun summary -> summary.EV)
            
            sortedSummaries |> Seq.iter (fun summary -> outputSummary outputContent includeDistributionChart summary)
            
            if includeEVChart then
                let keys = sortedSummaries |> Seq.map (fun summary -> summary.StrategyName)
                let values = sortedSummaries |> Seq.map (fun summary -> summary.EV)
            
                columnChart groupingName keys values
                
            outputContent ""
            outputContent ""
    )
    
let highlightStrategies tradeSummaries =
        
    let sortFunctions = [
        ("EV", fun (t:studies.Trading.TradeSummary) -> t.EV)
        //("Total Gain", fun (t:studies.ScreenerStudy.TradeSummary) -> t.TotalGain)
        //("Win %", fun (t:studies.ScreenerStudy.TradeSummary) -> t.WinPct)
        //("Avg Gain", fun (t:studies.ScreenerStudy.TradeSummary) -> t.AvgGainLoss)
    ]

    sortFunctions
    |> Seq.iter (fun (sortLabel, sortFunction) ->
        printfn $"Strategies sorted by: {sortLabel}"
        
        let summaryFunc = outputSummary outputToConsole false
        let descending =
            tradeSummaries
            |> Seq.sortByDescending sortFunction
            |> Seq.iter summaryFunc
            
        printfn ""
        printfn ""
    )
    
let saveTradeOutcomesToCsv resultsDirectory tradeSummaries =
    tradeSummaries
    |> Seq.iter(fun (summary:studies.Trading.TradeSummary) ->
        let invalidCharacters = System.IO.Path.GetInvalidFileNameChars()
        let cleanedFilename = invalidCharacters |> Seq.fold (fun (n:string) (c:char) -> n.Replace(c, '_')) summary.StrategyName
        let finalFilename = $"{cleanedFilename}.csv"
        let rows = studies.BreakoutStudy.createTradeOutcomesOutput summary.Trades
        let finalPath = System.IO.Path.Combine(resultsDirectory,finalFilename)
        rows.Save(finalPath)
    )

// %%
let inputSignals =
    inputFilename
    |> studies.BreakoutStudy.BreakoutSignalRecord.Load
    |> _.Rows
    |> Seq.map studies.BreakoutStudy.BreakoutSignalRecordWrapper
    |> List.ofSeq
    
outputToConsole $"Loaded {inputSignals.Length} signals"
// Out:
// Loaded 33518 signals

// %%
open MathNet.Numerics

// analyze data first
// visualize current slopes
let createHistogram label buckets (func:studies.BreakoutStudy.BreakoutSignalRecordWrapper->decimal) (filter:decimal->bool) (records:studies.BreakoutStudy.BreakoutSignalRecordWrapper list) =
    let slopes = records |> List.map func |> List.filter filter
    
    histogramChart label buckets slopes
    
let showStatistics label (func:studies.BreakoutStudy.BreakoutSignalRecordWrapper->float) (records:studies.BreakoutStudy.BreakoutSignalRecordWrapper list) =
    let values = records |> List.map func
    let stats = MathNet.Numerics.Statistics.DescriptiveStatistics(values)
    let mean = stats.Mean
    let stdDev = stats.StandardDeviation
    $"{label}: count: {records.Length}, mean: {mean}, stdDev: {stdDev}" |> outputToConsole
    stats
    
  
let priceSlopeStats = showStatistics "Price Slope" (fun s -> s.Row.PriceSlope |> float) inputSignals
createHistogram "Price Slope" 1000 (fun s -> s.Row.PriceSlope) (fun slope -> slope > -10m && slope < 10m) inputSignals

let priceAngleStats = showStatistics "Price Angle" (fun s -> s.Row.PriceDegrees |> float) inputSignals
createHistogram "Price Degrees" 10 (fun s -> s.Row.PriceDegrees) (fun s -> true) inputSignals

let volumeSlopeStats = showStatistics "Volume Slope" (fun s -> s.Row.VolumeSlope |> float) inputSignals
createHistogram "Volume Slope" 1000 (fun s -> s.Row.VolumeSlope) (fun volume -> true) inputSignals

let volumeAngleStats = showStatistics "Volume Angle" (fun s -> s.Row.VolumeDegrees |> float) inputSignals
createHistogram "Volume Degrees" 10 (fun s -> s.Row.VolumeDegrees) (fun s -> true) inputSignals

let volumeRateStats = showStatistics "Volume Rate" (fun s -> s.Row.BreakoutVolumeRate |> float) inputSignals
createHistogram "Volume Rate" 100 (fun s -> s.Row.BreakoutVolumeRate) (fun v -> true) inputSignals

// let signalsOutsidePriceSlope = inputSignals |> List.filter (fun s -> s.Row.PriceSlope > decimal (priceSlopeStats.Mean + priceSlopeStats.StandardDeviation * 1.5) * 1m)
// signalsOutsidePriceSlope |> List.sortBy (fun s -> s.Row.PriceSlope) |> List.iter(fun s -> $"{s.Row.Ticker} - {s.Row.Date} - {s.Row.PriceSlope}" |> outputToConsole)
// Out:
// Price Slope: count: 33518, mean: 0.0011054730540344673, stdDev: 1.544550753297985
// <div><div id="e15dfafe-331b-4e5b-8a84-6d5307be696d"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">
// var renderPlotly_e15dfafe331b4e5b8a846d5307be696d = function() {
//     var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-2.27.1.min'}}) || require;
//     fsharpPlotlyRequire(['plotly'], function(Plotly) {
//         var data = [{"type":"histogram","name":"Price Slope","x":[0.0212157598499062,-0.348101313320825,0.800667917448405,-0.0834718574108817,-0.258011257035647,-0.182979362101313,-0.0833461538461539,0.0290590994371482,-0.00563602251407132,0.151120075046904,0.107983114446529,0.115764540337711,-0.156352720450281,-0.0277673545966229,-0.0799765478424015,-0.0771219512195122,-0.00167073170731707,0.00261819887429644,-0.0223968105065666,-0.111496247654784,-0.0410290806754221,-0.0059624765478424,0.0147232645403377,-0.123003752345216,-0.0559662288930582,-0.0380900562851782,0.0752101313320826,0.00833020637898687,0.0620572232645403,-0.182025797373358,0.0910602532833021,0.674452833020638,0.740630938086304,0.768165290806754,-1.20348709193246,0.0573696060037524,-0.120093808630394,-0.0243949343339588,0.0166078799249531,-0.0740600375234522,0.0888667917448405,0.0748273921200751,-0.0730196998123827,0.062921200750469,0.0667129455909944,-0.0505342401500938,-0.113984990619137,-0.116137898686679,-0.235736085053159,-0.0685115697310817,0.175484052532833,0.0795565978736704,0.
    studies.Trading.strategyWithStopLossPercent verbosityOn StockPositionType.Long None None   // no stop, buy and hold or sell and hold
    studies.Trading.strategyWithStopLossPercent verbosityOn StockPositionType.Short None None
    studies.Trading.strategyWithStopLossPercent verbosityOn StockPositionType.Long (Some 5) None // no stop, but only hold for 5 bars
    studies.Trading.strategyWithStopLossPercent verbosityOn StockPositionType.Short (Some 5) None
    studies.Trading.strategyWithStopLossPercent verbosityOn StockPositionType.Long (Some 10) None // no stop, but only hold for 10 bars
    studies.Trading.strategyWithStopLossPercent verbosityOn StockPositionType.Short (Some 10) None    
    studies.Trading.strategyWithStopLossPercent verbosityOn StockPositionType.Long (Some 30) None // no stop, but only hold for 30 bars
    studies.Trading.strategyWithStopLossPercent verbosityOn StockPositionType.Short (Some 30) None
    studies.Trading.strategyWithStopLossPercent verbosityOn StockPositionType.Long (Some 60) None // no stop, but only hold for 60 bars
    studies.Trading.strategyWithStopLossPercent verbosityOn StockPositionType.Short (Some 60) None
    studies.Trading.strategyWithStopLossPercent verbosityOn StockPositionType.Long None (Some 0.05m) // 5% stop
    studies.Trading.strategyWithStopLossPercent verbosityOn StockPositionType.Short None (Some 0.05m)
    studies.Trading.strategyWithStopLossPercent verbosityOn StockPositionType.Long None (Some 0.1m) // 10% stop
    studies.Trading.strategyWithStopLossPercent verbosityOn StockPositionType.Short None (Some 0.1m)
    studies.Trading.strategyWithStopLossPercent verbosityOn StockPositionType.Long None (Some 0.2m) // 20% stop
    studies.Trading.strategyWithStopLossPercent verbosityOn StockPositionType.Short None (Some 0.2m)
    studies.Trading.strategyWithStopLossPercent verbosityOn StockPositionType.Long (Some 30) (Some 0.05m) // 5% stop plus holding at most 30 bars
    studies.Trading.strategyWithStopLossPercent verbosityOn StockPositionType.Short (Some 30) (Some 0.05m)
    studies.Trading.strategyWithStopLossPercent verbosityOn StockPositionType.Long (Some 60) (Some 0.05m) // 5% stop plus holding at most 60 bars
    studies.Trading.strategyWithStopLossPercent verbosityOn StockPositionType.Short (Some 60) (Some 0.05m)
    studies.Trading.strategyWithSignalOpenAsStop verbosityOn  // signal open as stop
    studies.Trading.strategyWithSignalCloseAsStop verbosityOn // signal close as stop
    studies.Trading.strategyWithTrailingStop verbosityOn StockPositionType.Long 0.1m  // trailing stop of 10%
    studies.Trading.strategyWithTrailingStop verbosityOn StockPositionType.Short 0.1m
    studies.Trading.strategyWithProfitTarget verbosityOn StockPositionType.Long 0.05m 0.1m
    studies.Trading.strategyWithProfitTarget verbosityOn StockPositionType.Short 0.05m 0.1m
    studies.Trading.strategyWithProfitTarget verbosityOn StockPositionType.Long 0.1m 0.2m
    studies.Trading.strategyWithProfitTarget verbosityOn StockPositionType.Short 0.1m 0.2m
]

let outcomes = 
    strategies
    |> studies.Trading.runTrades priceFunc signals
    |> Async.RunSynchronously
    |> Seq.toList

printfn "Finished running trades, generated:"
printfn $"{outcomes.Length} trade outcomes"
// Out:
// After filtering, we have 33518 signals
// Records: 33518, dates: 755, tickers: 3269, screenerIds: 1
// Minimum date: "2021-05-20"
// Maximum date: "2024-05-20"
//
// Ensured that data has prices
// Records: 33518, dates: 755, tickers: 3269, screenerIds: 1
// Minimum date: "2021-05-20"
// Maximum date: "2024-05-20"
//
// Executing trades...
//   Executing strategy 1...
//   Executing strategy 2...
//   Executing strategy 3...
//   Executing strategy 4...
//   Executing strategy 5...
//   Executing strategy 6...
//   Executing strategy 7...
//   Executing strategy 8...
//   Executing strategy 9...
//   Executing strategy 10...
//   Executing strategy 11...
//   Executing strategy 12...
//   Executing strategy 13...
//   Executing strategy 14...
//   Executing strategy 15...
//   Executing strategy 16...
//   Executing strategy 17...
//   Executing strategy 18...
//   Executing strategy 19...
//   Executing strategy 20...
//   Executing strategy 21...
//   Executing strategy 22...
//   Executing strategy 23...
//   Executing strategy 24...
//   Executing strategy 25...
//   Executing strategy 26...
//   Executing strategy 27...
//   Executing strategy 28...
// Finished running trades, generated:
// 577744 trade outcomes

// %%
// leave this cell for outcome checking from time to time when troubleshooting
//outcomes |> List.filter (fun (o:studies.ScreenerStudy.TradeOutcomeOutput.Row) -> o.Screenerid = 28 && o.OpenPrice < o.Sma200 && o.Strategy = "Buy")

// %%
printfn "Generating trade summaries..."
let tradeSummaries = outcomes |> createTradeSummaries |> Seq.toList
printfn $"{tradeSummaries.Length} summaries generated"

printfn "Saving trade summaries..."
tradeSummaries |> saveTradeOutcomesToCsv resultsDirectory
// Out:
// Generating trade summaries...
// 28 summaries generated
// Saving trade summaries...

// %%
"Highlighting trades" |> outputToConsole

tradeSummaries |> highlightStrategies
// Out:
// Highlighting trades
// Strategies sorted by: EV
// +14.14% EV -> 53.47% 	 62.81% 	 -41.79% 	 1.50 avg gain/loss 	 462.29 total gain  	 [3269 trades] 	 Buy
// +04.86% EV -> 32.39% 	 60.33% 	 -21.73% 	 2.78 avg gain/loss 	 345.26 total gain  	 [7097 trades] 	 Buy SL of 0.20%
// +02.68% EV -> 21.45% 	 58.48% 	 -12.55% 	 4.66 avg gain/loss 	 290.86 total gain  	 [10824 trades] 	 Buy SL of 0.10%
// +01.89% EV -> 14.49% 	 56.45% 	 -07.36% 	 7.67 avg gain/loss 	 283.97 total gain  	 [15000 trades] 	 Buy SL of 0.05%
// +00.97% EV -> 12.99% 	 42.31% 	 -05.20% 	 8.14 avg gain/loss 	 186.68 total gain  	 [19036 trades] 	 Buy and use signal open as stop
// +00.89% EV -> 51.00% 	 16.41% 	 -15.26% 	 1.08 avg gain/loss 	 155.35 total gain  	 [17198 trades] 	 Buy hold for 60 bars
// +00.68% EV -> 39.28% 	 20.37% 	 -12.06% 	 1.69 avg gain/loss 	 133.29 total gain  	 [19602 trades] 	 Buy SL of 0.10% PT of 0.20%
// +00.58% EV -> 17.31% 	 16.32% 	 -02.71% 	 6.01 avg gain/loss 	 151.65 total gain  	 [25223 trades] 	 Buy and use signal close as stop
// +00.41% EV -> 49.53% 	 12.37% 	 -11.32% 	 1.09 avg gain/loss 	 105.08 total gain  	 [24485 trades] 	 Buy hold for 30 bars
// +00.38% EV -> 38.02% 	 15.39% 	 -08.83% 	 1.74 avg gain/loss 	 83.17 total gain  	 [21434 trades] 	 Buy and use trailing stop, SL of 0.1%
// +00.34% EV -> 35.56% 	 13.16% 	 -06.73% 	 1.96 avg gain/loss 	 96.15 total gain  	 [27805 trades] 	 Buy hold for 30 bars SL of 0.05%
// +00.31% EV -> 28.66% 	 18.58% 	 -07.03% 	 2.64 avg gain/loss 	 74.20 total gain  	 [23754 trades] 	 Buy hold for 60 bars SL of 0.05%
// +00.27% EV -> 38.52% 	 11.90% 	 -07.01% 	 1.70 avg gain/loss 	 77.64 total gain  	 [28181 trades] 	 Buy SL of 0.05% PT of 0.10%
// +00.14% EV -> 50.16% 	 07.10% 	 -06.87% 	 1.03 avg gain/loss 	 50.71 total gain  	 [33161 trades] 	 Buy hold for 10 bars
// +00.08% EV -> 50.46% 	 05.28% 	 -05.21% 	 1.01 avg gain/loss 	 34.99 total gain  	 [33518 trades] 	 Buy hold for 5 bars
// -00.12% EV -> 49.17% 	 05.21% 	 -05.28% 	 0.99 avg gain/loss 	 -34.99 total gain  	 [33518 trades] 	 Sell hold for 5 bars
// -00.17% EV -> 49.64% 	 06.87% 	 -07.10% 	 0.97 avg gain/loss 	 -50.71 total gain  	 [33161 trades] 	 Sell hold for 10 bars
// -00.34% EV -> 34.52% 	 11.95% 	 -06.82% 	 1.75 avg gain/loss 	 -96.21 total gain  	 [28392 trades] 	 Sell hold for 30 bars SL of 0.05%
// -00.34% EV -> 35.86% 	 11.79% 	 -07.13% 	 1.65 avg gain/loss 	 -96.37 total gain  	 [28079 trades] 	 Sell SL of 0.05% PT of 0.10%
// -00.45% EV -> 50.32% 	 11.32% 	 -12.37% 	 0.92 avg gain/loss 	 -105.08 total gain  	 [24485 trades] 	 Sell hold for 30 bars
// -00.62% EV -> 39.25% 	 11.82% 	 -08.67% 	 1.36 avg gain/loss 	 -145.75 total gain  	 [23845 trades] 	 Sell and use trailing stop, SL of 0.1%
// -00.71% EV -> 26.94% 	 16.49% 	 -07.05% 	 2.34 avg gain/loss 	 -171.03 total gain  	 [24276 trades] 	 Sell hold for 60 bars SL of 0.05%
// -00.92% EV -> 48.91% 	 15.26% 	 -16.41% 	 0.93 avg gain/loss 	 -155.35 total gain  	 [17198 trades] 	 Sell hold for 60 bars
// -01.03% EV -> 34.34% 	 20.26% 	 -12.16% 	 1.67 avg gain/loss 	 -195.14 total gain  	 [19017 trades] 	 Sell SL of 0.10% PT of 0.20%
// -02.00% EV -> 13.51% 	 31.79% 	 -07.28% 	 4.37 avg gain/loss 	 -299.82 total gain  	 [14978 trades] 	 Sell SL of 0.05%
// -03.06% EV -> 20.22% 	 33.24% 	 -12.25% 	 2.71 avg gain/loss 	 -324.97 total gain  	 [10639 trades] 	 Sell SL of 0.10%
// -04.81% EV -> 28.95% 	 34.78% 	 -20.94% 	 1.66 avg gain/loss 	 -351.05 total gain  	 [7300 trades] 	 Sell SL of 0.20%
// -14.14% EV -> 46.53% 	 41.79% 	 -62.81% 	 0.67 avg gain/loss 	 -462.29 total gain  	 [3269 trades] 	 Sell

// %%
// tradeSummaries
// |> describeOutcomes None false false
//
// printfn "Finished"

// %%
let exploreCertainStrategies() =
    let strategiesOfInterest = [
        "SL of"
        "as stop"
    ]

    let summarizeSubset (name:string) =
        tradeSummaries
            |> Seq.filter (fun summary -> summary.StrategyName.Contains(name))
            |> Seq.sortByDescending (fun summary -> summary.EV)
            |> Seq.iter (fun summary -> 
                outputSummary outputToConsole false summary
            )

        printfn ""

    strategiesOfInterest |> List.iter (fun n -> summarizeSubset n)

// exploreCertainStrategies()

// %%
// sanity check, print random trades, look over them, investigate specific trades if needed
let positionDescription (signal:studies.Trading.TradeOutcome) =
    // it will consist of components that describe signal
    // gap up or gap down
    // price>20, price<20, put together into a string

    let signalDescription =
        match signal.Signal.Screenerid |> Option.defaultValue 0 with
        | 28 -> "New High"
        | 29 -> "Top Gainer"
        | 30 -> "Top Loser"
        | 31 -> "New Low"
        | _ -> "Generic Signal"
    
    String.concat " " [signalDescription]
        
let outcomeDescription (x:studies.Trading.TradeOutcome) =
    let gain = x.PercentGain.ToString("##.##%")
    let signal = x |> positionDescription
    printfn $"{x.Ticker} \t {x.Strategy} \t Profit: {gain} \t  {x.Opened:d} -> {x.Closed:d} \t {x.OpenPrice} -> {x.ClosePrice}. VA: {signal}, strat: {x.Strategy}"
    
let random = System.Random()

let tradeStrategyOfInterest = "Buy"

//let filterFunc x = x |> signalDescription |> _.Contains(tradeStrategyOfInterest)
let filterFunc (x:studies.Trading.TradeOutcome) = x.Strategy = tradeStrategyOfInterest

outcomes
|> Seq.filter filterFunc
|> Seq.sortBy (fun x -> random.NextInt64())
|> Seq.take 10
|> Seq.iter outcomeDescription

printfn ""
printfn $"Max gain trade from {tradeStrategyOfInterest}"

outcomes
|> Seq.filter filterFunc
|> Seq.sortByDescending (fun x -> x.PercentGain)
|> Seq.truncate 10
|> Seq.iter outcomeDescription

printfn ""
printfn "Max gain overall"

outcomes
|> Seq.maxBy (fun x -> x.PercentGain)
|> outcomeDescription
// Out:
// KARO 	 Buy 	 Profit: -18.78% 	  2021-07-30 -> 2024-05-21 	 35.9267 -> 29.18. VA: Generic Signal, strat: Buy
// UFI 	 Buy 	 Profit: -73.18% 	  2021-09-01 -> 2024-05-21 	 23.45 -> 6.29. VA: Generic Signal, strat: Buy
// MANH 	 Buy 	 Profit: 103.32% 	  2022-06-16 -> 2024-05-21 	 110.99 -> 225.67. VA: Generic Signal, strat: Buy
// TWIN 	 Buy 	 Profit: 11.02% 	  2021-10-29 -> 2024-05-21 	 12.8 -> 14.21. VA: Generic Signal, strat: Buy
// IDR 	 Buy 	 Profit: 9.64% 	  2024-04-23 -> 2024-05-21 	 9.54 -> 10.46. VA: Generic Signal, strat: Buy
// SEED 	 Buy 	 Profit: -38.87% 	  2022-07-22 -> 2024-05-21 	 9.75 -> 5.96. VA: Generic Signal, strat: Buy
// NUWE 	 Buy 	 Profit: -99.7% 	  2022-03-09 -> 2024-05-21 	 90.3 -> 0.269. VA: Generic Signal, strat: Buy
// VSCO 	 Buy 	 Profit: -57.22% 	  2021-12-20 -> 2024-05-21 	 48.08 -> 20.57. VA: Generic Signal, strat: Buy
// BFH 	 Buy 	 Profit: -4.71% 	  2022-06-15 -> 2024-05-21 	 44.63 -> 42.53. VA: Generic Signal, strat: Buy
// EWTX 	 Buy 	 Profit: 86.16% 	  2023-02-27 -> 2024-05-21 	 9.61 -> 17.89. VA: Generic Signal, strat: Buy
//
// Max gain trade from Buy
// SMCI 	 Buy 	 Profit: 2360.18% 	  2021-09-20 -> 2024-05-21 	 36.54 -> 898.95. VA: Generic Signal, strat: Buy
// AMR 	 Buy 	 Profit: 1179.76% 	  2021-07-21 -> 2024-05-21 	 23.76 -> 304.07. VA: Generic Signal, strat: Buy
// TDW 	 Buy 	 Profit: 898.79% 	  2021-08-26 -> 2024-05-21 	 10.72 -> 107.07. VA: Generic Signal, strat: Buy
// MOD 	 Buy 	 Profit: 837.45% 	  2021-10-29 -> 2024-05-21 	 10.91 -> 102.276. VA: Generic Signal, strat: Buy
// VRT 	 Buy 	 Profit: 712.54% 	  2022-08-04 -> 2024-05-21 	 12.2 -> 99.13. VA: Generic Signal, strat: Buy
// WFRD 	 Buy 	 Profit: 665.16% 	  2021-09-08 -> 2024-05-21 	 16.16 -> 123.65. VA: Generic Signal, strat: Buy
// ANF 	 Buy 	 Profit: 659.01% 	  2022-08-09 -> 2024-05-21 	 19.03 -> 144.44. VA: Generic Signal, strat: Buy
// SEZL 	 Buy 	 Profit: 650.22% 	  2023-11-21 -> 2024-05-21 	 10.2197 -> 76.67. VA: Generic Signal, strat: Buy
// ROOT 	 Buy 	 Profit: 531.03% 	  2023-10-11 -> 2024-05-21 	 9.86 -> 62.22. VA: Generic Signal, strat: Buy
// MSTR 	 Buy 	 Profit: 528.94% 	  2022-09-12 -> 2024-05-21 	 263.21 -> 1655.42. VA: Generic Signal, strat: Buy
//
// Max gain overall
// SMCI 	 Buy and use signal open as stop 	 Profit: 2381.23% 	  2022-04-18 -> 2024-05-21 	 36.23 -> 898.95. VA: Generic Signal, strat: Buy and use signal open as stop

// %% [raw]
// // investigating what happened with the trade and why it went as it went
// // turn into code if you want to exec
// let signals =
//     inputFilename
//     |> studies.ScreenerStudy.SignalWithPriceProperties.Load
//     |> _.Rows
//
// let tickerOfInterest = "MDGL"
//
// let signalsOfInterest =
//     signals
//     |> Seq.filter (fun signal -> signal.Ticker = tickerOfInterest)
//
// let strategy = studies.Trading.strategyWithTrailingStop false StockPositionType.Long 0.1m
//
// let outcomesOfInterest = studies.Trading.runTrades priceFunc signalsOfInterest [strategy] |> Async.RunSynchronously
//
// outcomesOfInterest
// |> Seq.iter ( fun outcome ->
//     outcome |> outcomeDescription
//     printfn ""
// )

// %%
Plotly.NET.Defaults.DefaultWidth <- 900

let metrics = [
    ("EV", fun (s:studies.Trading.TradeSummary) -> s.EV)
    ("Win/Loss", fun s -> s.AvgGainLoss)
    ("Win %", fun s -> s.WinPct)
    ("Avg Win", fun s -> s.AvgWin)
    ("Avg Loss", fun s -> s.AvgLoss)
    ("Number of Trades", fun s -> s.NumberOfTrades)
]

metrics
|> List.iter( fun (label,metricFunc) ->

    outputToConsole $"sorting for {label}..."
    
    let sorted = tradeSummaries |> Seq.sortByDescending metricFunc |> Seq.toList
    
    let values = sorted |> List.map metricFunc
    let keys = sorted |> List.map (fun summary -> summary.StrategyName)

    outputToConsole $"mapped keys and values for {label}, charting..."
    
    // values |> List.zip keys |> List.iter (fun (l,v) -> outputToConsole $"{l}: {v}")
    
    let column = 
        Chart.Column(values = values, Keys = keys)
        |> Chart.withYAxisStyle (TitleText = label)
    
    column.Display() |> ignore
    
    outputToConsole ""
)
// Out:
// sorting for EV...
// mapped keys and values for EV, charting...
// <div><div id="8b2f8b0b-3156-4822-995d-55b2ff06e330"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">
// var renderPlotly_8b2f8b0b31564822995d55b2ff06e330 = function() {
//     var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-2.27.1.min'}}) || require;
//     fsharpPlotlyRequire(['plotly'], function(Plotly) {
//         var data = [{"type":
"height":600,"template":{"layout":{"title":{"x":0.05},"font":{"color":"rgba(42, 63, 95, 1.0)"},"paper_bgcolor":"rgba(255, 255, 255, 1.0)","plot_bgcolor":"rgba(229, 236, 246, 1.0)","autotypenumbers":"strict","colorscale":{"diverging":[[0.0,"#8e0152"],[0.1,"#c51b7d"],[0.2,"#de77ae"],[0.3,"#f1b6da"],[0.4,"#fde0ef"],[0.5,"#f7f7f7"],[0.6,"#e6f5d0"],[0.7,"#b8e186"],[0.8,"#7fbc41"],[0.9,"#4d9221"],[1.0,"#276419"]],"sequential":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"sequentialminus":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]},"hovermode":"closest","hoverlabel":{"align":"left"},"coloraxis":{"colorbar":{"outlinewidth":0.0,"ticks":""}},"geo":{"showland":true,"landcolor":"rgba(229, 236, 246, 1.0)","showlakes":true,"lakecolor":"rgba(255, 255, 255, 1.0)","subunitcolor":"rgba(255, 255, 255, 1.0)","bgcolor":"rgba(255, 255, 255, 1.0)"},"mapbox":{"style":"light"},"polar":{"bgcolor":"rgba(229, 236, 246, 1.0)","radialaxis":{"linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)","ticks":""},"angularaxis":{"linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)","ticks":""}},"scene":{"xaxis":{"ticks":"","linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)","gridwidth":2.0,"zerolinecolor":"rgba(255, 255, 255, 1.0)","backgroundcolor":"rgba(229, 236, 246, 1.0)","showbackground":true},"yaxis":{"ticks":"","linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)","gridwidth":2.0,"zerolinecolor":"rgba(255, 255, 255, 1.0)","backgroundcolor":"rgba(229, 236, 246, 1.0)","showbackground":true},"zaxis":{"ticks":"","linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)","gridwidth":2.0,"zerolinecolor":"rgba(255, 255, 255, 1.0)","backgroundcolor":"rgba(229, 236, 246, 1.0)","showbackground":true}},"ternary":{"aaxis":{"ticks":"","linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)"},"baxis":{"ticks":"","linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)"},"caxis":{"ticks":"","linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)"},"bgcolor":"rgba(229, 236, 246, 1.0)"},"xaxis":{"title":{"standoff":15},"ticks":"","automargin":"height+width+left+right+top+bottom","linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)","zerolinecolor":"rgba(255, 255, 255, 1.0)","zerolinewidth":2.0},"yaxis":{"title":{"standoff":15},"ticks":"","automargin":"height+width+left+right+top+bottom","linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)","zerolinecolor":"rgba(255, 255, 255, 1.0)","zerolinewidth":2.0},"annotationdefaults":{"arrowcolor":"#2a3f5f","arrowhead":0,"arrowwidth":1},"shapedefaults":{"line":{"color":"rgba(42, 63, 95, 1.0)"}},"colorway":["rgba(99, 110, 250, 1.0)","rgba(239, 85, 59, 1.0)","rgba(0, 204, 150, 1.0)","rgba(171, 99, 250, 1.0)","rgba(255, 161, 90, 1.0)","rgba(25, 211, 243, 1.0)","rgba(255, 102, 146, 1.0)","rgba(182, 232, 128, 1.0)","rgba(255, 151, 255, 1.0)","rgba(254, 203, 82, 1.0)"]},"data":{"bar":[{"marker":{"line":{"color":"rgba(229, 236, 246, 1.0)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"error_x":{"color":"rgba(42, 63, 95, 1.0)"},"error_y":{"color":"rgba(42, 63, 95, 1.0)"}}],"barpolar":[{"marker":{"line":{"color":"rgba(229, 236, 246, 1.0)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}}}],"carpet":[{"aaxis":{"linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, ...
// sorting for Win %...
// mapped keys and values for Win %, charting...
// <div><div id="fb10718a-2c3b-41d6-8882-628b00c8392e"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">
// var renderPlotly_fb10718a2c3b41d68882628b00c8392e = function() {
//     var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-2.27.1.min'}}) || require;
//     fsharpPlotlyRequire(['plotly'], function(Plotly) {
//         var data = [{"type":"bar","x":["Buy","Buy hold for 60 bars","Buy hold for 5 bars","Sell hold for 30 bars","Buy hold for 10 bars","Sell hold for 10 bars","Buy hold for 30 bars","Sell hold for 5 bars","Sell hold for 60 bars","Sell","Buy SL of 0.10% PT of 0.20%","Sell and use trailing stop, SL of 0.1%","Buy SL of 0.05% PT of 0.10%","Buy and use trailing stop, SL of 0.1%","Sell SL of 0.05% PT of 0.10%","Buy hold for 30 bars SL of 0.05%","Sell hold for 30 bars SL of 0.05%","Sell SL of 0.10% PT of 0.20%","Buy SL of 0.20%","Sell SL of 0.20%","Buy hold for 60 bars SL of 0.05%","Sell hold for 60 bars SL of 0.05%","Buy SL of 0.10%","Sell SL of 0.10%","Buy and use signal close as stop","Buy SL of 0.05%","Sell SL of 0.05%","Buy and use signal open as stop"],"y":[0.5347200978892627714897522178,0.5100011629259216187928828934,0.504594546213974580822244764,0.5032468858484786604043291811,0.5015530291607611350683031272,0.4964265251349476795030306686,0.495282826220134776393710435,0.491676114326630467211647473,0.4890684963367833469008024189,0.4652799021107372285102477822,0.3927660442811957963473114988,0.3925351226672258335080729713,0.3851886022497427344664845108,0.3802370066249883362881403378,0.3585953915737739948003846291,0.3555835281424204279805790325,0.3452380952380952380952380952,0.3433769784929273807645790608,0.3239396928279554741440045089,0.2894520547945205479452054795,0.2866464595436558053380483287,0.2694430713461855330367441094,0.2145232815964523281596452328,0.2021806560766989378701005734,0.1730959838242873567775443048,0.1449333333333333333333333333,0.1351315262384831085592201896,0.1298592141206135742803109897],"orientation":"v","marker":{"pattern":{}}}];
//         var layout = {"width":900,"height":600,"template":{"layout":{"title":{"x":0.05},"font":{"color":"rgba(42, 63, 95, 1.0)"},"paper_bgcolor":"rgba(255, 255, 255, 1.0)","plot_bgcolor":"rgba(229, 236, 246, 1.0)","autotypenumbers":"strict","colorscale":{"diverging":[[0.0,"#8e0152"],[0.1,"#c51b7d"],[0.2,"#de77ae"],[0.3,"#f1b6da"],[0.4,"#fde0ef"],[0.5,"#f7f7f7"],[0.6,"#e6f5d0"],[0.7,"#b8e186"],[0.8,"#7fbc41"],[0.9,"#4d9221"],[1.0,"#276419"]],"sequential":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"sequentialminus":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]},"hovermode":"closest","hoverlabel":{"align":"left"},"coloraxis":{"colorbar":{"outlinewidth":0.0,"ticks":""}},"geo":{"showland":true,"landcolor":"rgba(229, 236, 246, 1.0)","showlakes":true,"lakecolor":"rgba(255, 255, 255, 1.0)","subunitcolor":"rgba(255, 255, 255, 1.0)","bgcolor":"rgba(255, 255, 255, 1.0)"},"mapbox":{"style":"light"},"polar":{"bgcolor":"rgba(229, 236, 246, 1.0)","radialaxis":{"linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)","ticks":""},"angularaxis":{"linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)","ticks":""}},"scene":{"xaxis":{"ticks":"","linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)","gridwidth":2.0,"zerolinecolor":"rgba(255, 255, 255, 1.0)","backgroundcolor":"rgba(229, 236, 246, 1.0)","showbackground":true},"yaxis":{"ticks":"","linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)","gridwidth":2.0,"zerolinecolor":"rgba(255, 255, 255, 1.0)","backgroundcolor":"rgba(229, 236, 246, 1.0)","showbackground":true},"zaxis":{"ticks":"","linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)","gridwidth":2.0,"zerolinecolor":"rgba(255, 255, 255, 1.0)","backgroundcolor":"rgba(229, 236, 246, 1.0)","showbackground":true}},"ternary":{"aaxis":{"ticks":"","linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)"},"baxis":{"ticks":"","linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)"},"caxis":{"ticks":"","linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)"},"bgcolor":"rgba(229, 236, 246, 1.0)"},"xaxis":{"title":{"standoff":15},"ticks":"","automargin":"height+width+left+right+top+bottom","linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)","zerolinecolor":"rgba(255, 255, 255, 1.0)","zerolinewidth":2.0},"yaxis":{"title":{"standoff":15},"ticks":"","automargin":"height+width+left+right+top+bottom","linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)","zerolinecolor":"rgba(255, 255, 255, 1.0)","zerolinewidth":2.0},"annotationdefaults":{"arrowcolor":"#2a3f5f","arrowhead":0,"arrowwidth":1},"shapedefaults":{"line":{"color":"rgba(42, 63, 95, 1.0)"}},"colorway":["rgba(99, 110, 250, 1.0)","rgba(239, 85, 59, 1.0)","rgba(0, 204, 150, 1.0)","rgba(171, 99, 250, 1.0)","rgba(255, 161, 90, 1.0)","rgba(25, 211, 243, 1.0)","rgba(255, 102, 146, 1.0)","rgba(182, 232, 128, 1.0)","rgba(255, 151, 255, 1.0)","rgba(254, 203, 82, 1.0)"]},"data":{"bar":[{"marker":{"line":{"color":"rgba(229, 236, 246, 1.0)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"error_x":{"color":"rgba(42, 63, 95, 1.0)"},"error_y":{"color":"rgba(42, 63, 95, 1.0)"}}],"barpolar":[{"marker":{"line":{"color":"rgba(229, 236, 246, 1.0)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}}}],"carpet":[{"aaxis":{"linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, ...
// sorting for Avg Win...
// mapped keys and values for Avg Win, charting...
// <div><div id="946585bf-b109-4b9e-922d-bdc22a5a46a0"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">
// var renderPlotly_946585bfb1094b9e922dbdc22a5a46a0 = function() {
//     var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-2.27.1.min'}}) || require;
//     fsharpPlotlyRequire(['plotly'], function(Plotly) {
//         var data = [{"type":"bar","x":["Buy","Buy SL of 0.20%","Buy SL of 0.10%","Buy SL of 0.05%","Buy and use signal open as stop","Sell","Sell SL of 0.20%","Sell SL of 0.10%","Sell SL of 0.05%","Buy SL of 0.10% PT of 0.20%","Sell SL of 0.10% PT of 0.20%","Buy hold for 60 bars SL of 0.05%","Sell hold for 60 bars SL of 0.05%","Buy hold for 60 bars","Buy and use signal close as stop","Buy and use trailing stop, SL of 0.1%","Sell hold for 60 bars","Buy hold for 30 bars SL of 0.05%","Buy hold for 30 bars","Sell hold for 30 bars SL of 0.05%","Buy SL of 0.05% PT of 0.10%","Sell and use trailing stop, SL of 0.1%","Sell SL of 0.05% PT of 0.10%","Sell hold for 30 bars","Buy hold for 10 bars","Sell hold for 10 bars","Buy hold for 5 bars","Sell hold for 5 bars"],"y":[0.6280878875392529964387408622,0.603319416866399189789063858,0.5847826776963401647219548486,0.5645375853018782551725454724,0.4230664898625100060455021679,0.
fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-2.27.1.min'}}) || require;
//     fsharpPlotlyRequire(['plotly'], function(Plotly) {
//         var data = [{"type":"bar","x":["Buy hold for 5 bars","Sell hold for 5 bars","Buy hold for 10 bars","Sell hold for 10 bars","Sell hold for 30 bars SL of 0.05%","Buy SL of 0.05% PT of 0.10%","Sell SL of 0.05% PT of 0.10%","Buy hold for 30 bars SL of 0.05%","Buy and use signal close as stop","Buy hold for 30 bars","Sell hold for 30 bars","Sell hold for 60 bars SL of 0.05%","Sell and use trailing stop, SL of 0.1%","Buy hold for 60 bars SL of 0.05%","Buy and use trailing stop, SL of 0.1%","Buy SL of 0.10% PT of 0.20%","Buy and use signal open as stop","Sell SL of 0.10% PT of 0.20%","Buy hold for 60 bars","Sell hold for 60 bars","Buy SL of 0.05%","Sell SL of 0.05%","Buy SL of 0.10%","Sell SL of 0.10%","Sell SL of 0.20%","Buy SL of 0.20%","Buy","Sell"],"y":[33518.0,33518.0,33161.0,33161.0,28392.0,28181.0,28079.0,27805.0,25223.0,24485.0,24485.0,24276.0,23845.0,23754.0,21434.0,19602.0,19036.0,19017.0,17198.0,17198.0,15000.0,14978.0,10824.0,10639.0,7300.0,7097.0,3269.0,3269.0],"orientation":"v","marker":{"pattern":{}}}];
//         var layout = {"width":900,"height":600,"template":{"layout":{"title":{"x":0.05},"font":{"color":"rgba(42, 63, 95, 1.0)"},"paper_bgcolor":"rgba(255, 255, 255, 1.0)","plot_bgcolor":"rgba(229, 236, 246, 1.0)","autotypenumbers":"strict","colorscale":{"diverging":[[0.0,"#8e0152"],[0.1,"#c51b7d"],[0.2,"#de77ae"],[0.3,"#f1b6da"],[0.4,"#fde0ef"],[0.5,"#f7f7f7"],[0.6,"#e6f5d0"],[0.7,"#b8e186"],[0.8,"#7fbc41"],[0.9,"#4d9221"],[1.0,"#276419"]],"sequential":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"sequentialminus":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]},"hovermode":"closest","hoverlabel":{"align":"left"},"coloraxis":{"colorbar":{"outlinewidth":0.0,"ticks":""}},"geo":{"showland":true,"landcolor":"rgba(229, 236, 246, 1.0)","showlakes":true,"lakecolor":"rgba(255, 255, 255, 1.0)","subunitcolor":"rgba(255, 255, 255, 1.0)","bgcolor":"rgba(255, 255, 255, 1.0)"},"mapbox":{"style":"light"},"polar":{"bgcolor":"rgba(229, 236, 246, 1.0)","radialaxis":{"linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)","ticks":""},"angularaxis":{"linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)","ticks":""}},"scene":{"xaxis":{"ticks":"","linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)","gridwidth":2.0,"zerolinecolor":"rgba(255, 255, 255, 1.0)","backgroundcolor":"rgba(229, 236, 246, 1.0)","showbackground":true},"yaxis":{"ticks":"","linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)","gridwidth":2.0,"zerolinecolor":"rgba(255, 255, 255, 1.0)","backgroundcolor":"rgba(229, 236, 246, 1.0)","showbackground":true},"zaxis":{"ticks":"","linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)","gridwidth":2.0,"zerolinecolor":"rgba(255, 255, 255, 1.0)","backgroundcolor":"rgba(229, 236, 246, 1.0)","showbackground":true}},"ternary":{"aaxis":{"ticks":"","linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)"},"baxis":{"ticks":"","linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)"},"caxis":{"ticks":"","linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)"},"bgcolor":"rgba(229, 236, 246, 1.0)"},"xaxis":{"title":{"standoff":15},"ticks":"","automargin":"height+width+left+right+top+bottom","linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)","zerolinecolor":"rgba(255, 255, 255, 1.0)","zerolinewidth":2.0},"yaxis":{"title":{"standoff":15},"ticks":"","automargin":"height+width+left+right+top+bottom","linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, 255, 1.0)","zerolinecolor":"rgba(255, 255, 255, 1.0)","zerolinewidth":2.0},"annotationdefaults":{"arrowcolor":"#2a3f5f","arrowhead":0,"arrowwidth":1},"shapedefaults":{"line":{"color":"rgba(42, 63, 95, 1.0)"}},"colorway":["rgba(99, 110, 250, 1.0)","rgba(239, 85, 59, 1.0)","rgba(0, 204, 150, 1.0)","rgba(171, 99, 250, 1.0)","rgba(255, 161, 90, 1.0)","rgba(25, 211, 243, 1.0)","rgba(255, 102, 146, 1.0)","rgba(182, 232, 128, 1.0)","rgba(255, 151, 255, 1.0)","rgba(254, 203, 82, 1.0)"]},"data":{"bar":[{"marker":{"line":{"color":"rgba(229, 236, 246, 1.0)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"error_x":{"color":"rgba(42, 63, 95, 1.0)"},"error_y":{"color":"rgba(42, 63, 95, 1.0)"}}],"barpolar":[{"marker":{"line":{"color":"rgba(229, 236, 246, 1.0)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}}}],"carpet":[{"aaxis":{"linecolor":"rgba(255, 255, 255, 1.0)","gridcolor":"rgba(255, 255, ...
// input.fsx (9,35)-(9,51) typecheck warning This expression uses the implicit conversion 'Decimal.op_Implicit(value: int) : decimal' to convert type 'int' to type 'decimal'. See https://aka.ms/fsharp-implicit-convs. This warning may be disabled using '#nowarn "3391".

// %%
// let's take only the trades where EV is positive
outputToConsole "Positive EVs only, sorted by EV descending"

tradeSummaries
|> List.filter (fun s -> s.EV > 0m)
|> List.sortByDescending (fun s -> s.EV)
|> List.iter (fun s -> outputSummary outputToConsole false s)
// Out:
// Positive EVs only, sorted by EV descending
// +14.14% EV -> 53.47% 	 62.81% 	 -41.79% 	 1.50 avg gain/loss 	 462.29 total gain  	 [3269 trades] 	 Buy
// +04.86% EV -> 32.39% 	 60.33% 	 -21.73% 	 2.78 avg gain/loss 	 345.26 total gain  	 [7097 trades] 	 Buy SL of 0.20%
// +02.68% EV -> 21.45% 	 58.48% 	 -12.55% 	 4.66 avg gain/loss 	 290.86 total gain  	 [10824 trades] 	 Buy SL of 0.10%
// +01.89% EV -> 14.49% 	 56.45% 	 -07.36% 	 7.67 avg gain/loss 	 283.97 total gain  	 [15000 trades] 	 Buy SL of 0.05%
// +00.97% EV -> 12.99% 	 42.31% 	 -05.20% 	 8.14 avg gain/loss 	 186.68 total gain  	 [19036 trades] 	 Buy and use signal open as stop
// +00.89% EV -> 51.00% 	 16.41% 	 -15.26% 	 1.08 avg gain/loss 	 155.35 total gain  	 [17198 trades] 	 Buy hold for 60 bars
// +00.68% EV -> 39.28% 	 20.37% 	 -12.06% 	 1.69 avg gain/loss 	 133.29 total gain  	 [19602 trades] 	 Buy SL of 0.10% PT of 0.20%
// +00.58% EV -> 17.31% 	 16.32% 	 -02.71% 	 6.01 avg gain/loss 	 151.65 total gain  	 [25223 trades] 	 Buy and use signal close as stop
// +00.41% EV -> 49.53% 	 12.37% 	 -11.32% 	 1.09 avg gain/loss 	 105.08 total gain  	 [24485 trades] 	 Buy hold for 30 bars
// +00.38% EV -> 38.02% 	 15.39% 	 -08.83% 	 1.74 avg gain/loss 	 83.17 total gain  	 [21434 trades] 	 Buy and use trailing stop, SL of 0.1%
// +00.34% EV -> 35.56% 	 13.16% 	 -06.73% 	 1.96 avg gain/loss 	 96.15 total gain  	 [27805 trades] 	 Buy hold for 30 bars SL of 0.05%
// +00.31% EV -> 28.66% 	 18.58% 	 -07.03% 	 2.64 avg gain/loss 	 74.20 total gain  	 [23754 trades] 	 Buy hold for 60 bars SL of 0.05%
// +00.27% EV -> 38.52% 	 11.90% 	 -07.01% 	 1.70 avg gain/loss 	 77.64 total gain  	 [28181 trades] 	 Buy SL of 0.05% PT of 0.10%
// +00.14% EV -> 50.16% 	 07.10% 	 -06.87% 	 1.03 avg gain/loss 	 50.71 total gain  	 [33161 trades] 	 Buy hold for 10 bars
// +00.08% EV -> 50.46% 	 05.28% 	 -05.21% 	 1.01 avg gain/loss 	 34.99 total gain  	 [33518 trades] 	 Buy hold for 5 bars

// %%
let benchmarkStrategyName = "Sell"

//tradeSummaries |> List.map _.StrategyName |> List.distinct |> List.iter outputToConsole
let benchmarkStrategy = tradeSummaries |> List.find (fun s -> s.StrategyName = benchmarkStrategyName)

outputSummary outputToConsole false benchmarkStrategy
// Out:
// -14.14% EV -> 46.53% 	 41.79% 	 -62.81% 	 0.67 avg gain/loss 	 -462.29 total gain  	 [3269 trades] 	 Sell

// %%
//let newHighsWithPriceBelow20 = outcomes |> Seq.filter (fun (o:studies.Trading.TradeOutcomeOutput.Row) -> o.Screenerid |> Option.defaultValue 0 = 28 && o.OpenPrice < (o.Sma20 |> Option.defaultValue 0m) )

//let count = newHighsWithPriceBelow20 |> Seq.length

//printfn "Found %i" count
//newHighsWithPriceBelow20 |> Seq.take 10 |> Seq.iter outcomeDescription

// %%
//let topLoserPriceAbove20 = outcomes |> Seq.filter (fun (o:studies.Trading.TradeOutcomeOutput.Row) -> o.Screenerid |> Option.defaultValue 0 = 30 && o.OpenPrice > (o.Sma20 |> Option.defaultValue 0m) && o.Strategy = "Sell")

//let count = topLoserPriceAbove20 |> Seq.length

//printfn "Found %i" count
//topLoserPriceAbove20 |> Seq.take 30 |> Seq.iter outcomeDescription

// %%
type InternalOutcomeSummary = {
    ev: decimal
    win_pct: decimal
    avg_win: decimal
    avg_loss: decimal
    numberOfTrades: int
    label: string
    outcomes: studies.BreakoutStudy.BreakoutTradeOutcomeRecord.Row seq
}
    with
        member this.Describe() =
            $"EV : {this.ev:P}\t Win: {this.win_pct:P}, Avg Win: {this.avg_win:P}, Avg Loss: {this.avg_loss:P}, total: {this.numberOfTrades}, {this.label}"

// %%
let summarizeRecords label (outcomes:studies.BreakoutStudy.BreakoutTradeOutcomeRecord.Row seq) = 
    let numberOfTrades = outcomes |> Seq.length
    
    if numberOfTrades = 0 then
        {
            ev = 0m
            win_pct = 0m
            avg_win = 0m
            avg_loss = 0m
            numberOfTrades = 0
            label = label
            outcomes = []
        }
    else
        let winners = outcomes |> Seq.filter (fun o -> o.PercentGain > 0m)
        let losers = outcomes |> Seq.filter (fun o -> o.PercentGain < 0m)
        let numberOfWinners = winners |> Seq.length
        let numberOfLosers = losers |> Seq.length
        let win_pct = decimal numberOfWinners / decimal numberOfTrades
        let avg_win =
            match numberOfWinners with
            | 0 -> 0m
            | _ -> winners |> Seq.averageBy (_.PercentGain)
        let avg_loss =
            match numberOfLosers with
            | 0 -> 0m
            | _ -> losers |> Seq.averageBy (_.PercentGain)
        let avg_gain_loss =
            match avg_loss with
            | 0m -> 0m
            | _ -> avg_win / avg_loss |> Math.Abs
        let ev = win_pct * avg_win - (1m - win_pct) * (avg_loss |> Math.Abs)
        let totalGain = outcomes |> Seq.sumBy (_.PercentGain)

        {
            ev = ev
            win_pct = win_pct
            avg_win = avg_win
            avg_loss = avg_loss
            numberOfTrades = numberOfTrades
            label = label
            outcomes = outcomes
        }

// %%
let load filename =
    let filepath = @$"{resultsDirectory}\{filename}"
    studies.BreakoutStudy.BreakoutTradeOutcomeRecord.Load(filepath)
    
let summarize (dataSetName:string) (records:studies.BreakoutStudy.BreakoutTradeOutcomeRecord.Row seq) =

    [
        summarizeRecords $"{dataSetName} All" records

        // let's take only those that have volume rate above 
        records |> Seq.filter (fun r -> r.BreakoutVolumeRate >= 1m && r.BreakoutVolumeRate < 2m) |> summarizeRecords $"{dataSetName} Breakout 1-2"
        records |> Seq.filter (fun r -> r.BreakoutVolumeRate >= 2m && r.BreakoutVolumeRate < 3m) |> summarizeRecords $"{dataSetName} Breakout 2-3"
        records |> Seq.filter (fun r -> r.BreakoutVolumeRate >= 3m && r.BreakoutVolumeRate < 4m) |> summarizeRecords $"{dataSetName} Breakout 3-4"
        records |> Seq.filter (fun r -> r.BreakoutVolumeRate >= 4m && r.BreakoutVolumeRate < 5m) |> summarizeRecords $"{dataSetName} Breakout 4-5"
        records |> Seq.filter (fun r -> r.BreakoutVolumeRate >= 5m) |> summarizeRecords $"{dataSetName} Breakout 5+"
        records |> Seq.filter (fun r -> r.BreakoutVolumeRate >= 4m && r.PriceDegrees >= 20m) |> summarizeRecords $"{dataSetName} Breakout 4x+ & Price Angle <= -20 degrees"

        // let's see what's the difference between rising and falling price slope
        records |> Seq.filter (fun r -> r.PriceSlope < 0m) |> summarizeRecords $"{dataSetName} Negative Price Slope"
        records |> Seq.filter (fun r -> r.PriceSlope > 0m) |> summarizeRecords $"{dataSetName} Positive Price Slope"
    
        // let's see what the angle breakouts look like
        //records |> Seq.filter (fun r -> r.PriceDegrees <= -40m) |> summarizeRecords "Price deg < -40"
        //records |> Seq.filter (fun r -> r.PriceDegrees < -20m && r.PriceDegrees > -40m) |> summarizeRecords "Price deg -40 to -20"
        //records |> Seq.filter (fun r -> r.PriceDegrees < 20m  && r.PriceDegrees >= -20m) |> summarizeRecords "Price deg -20 to 20"
        //records |> Seq.filter (fun r -> r.PriceDegrees < 40m && r.PriceDegrees >= 20m) |> summarizeRecords "Price deg 20 to 40"
        //records |> Seq.filter (fun r -> r.PriceDegrees >= 40m) |> summarizeRecords "Price deg > 40"
    ]

// %%
let nofilter rows = rows
let above30PriceFilter rows = Seq.filter (fun (r:studies.BreakoutStudy.BreakoutTradeOutcomeRecord.Row) -> r.OpenPrice >= 30m) rows
let industryCycleUp rows = Seq.filter (fun (r:studies.BreakoutStudy.BreakoutTradeOutcomeRecord.Row) -> r.IndustryCycle = "Up") rows
let industryCycleDown rows = Seq.filter (fun (r:studies.BreakoutStudy.BreakoutTradeOutcomeRecord.Row) -> r.IndustryCycle = "Down") rows
let spyShortTermUp rows = Seq.filter (fun (r:studies.BreakoutStudy.BreakoutTradeOutcomeRecord.Row) -> r.SpyShortTermCycle = "Up") rows
let spyShortTermDown rows = Seq.filter (fun (r:studies.BreakoutStudy.BreakoutTradeOutcomeRecord.Row) -> r.SpyShortTermCycle = "Down") rows
let spyLongTermUp rows =  Seq.filter (fun (r:studies.BreakoutStudy.BreakoutTradeOutcomeRecord.Row) -> r.SpyLongTermCycle = "Up") rows
let spyLongTermDown rows =  Seq.filter (fun (r:studies.BreakoutStudy.BreakoutTradeOutcomeRecord.Row) -> r.SpyLongTermCycle = "Down") rows

let filters = [
    "None", nofilter
    "Price above 30", above30PriceFilter
    "Industry Cycle Up", industryCycleUp
    "Industry Cycle Down", industryCycleDown
    "Spy Short Term Up", spyShortTermUp
    "Spy Short Term Down", spyShortTermDown
    "Spy Long Term Up", spyLongTermUp
    "Spy Long Term Down", spyLongTermDown    
]

let results =
    filters
    |> List.collect(fun (filterName, filterFunc) ->

        $"************ Filter applied: {filterName}" |> outputToConsole

        tradeSummaries
        |> List.map (fun s -> s.StrategyName)
        |> List.collect (fun strategyName ->
            let csv = load $"{strategyName}.csv"
            csv.Rows |> filterFunc |> summarize $"{filterName}: {strategyName}" 
        )
    )
// Out:
// ************ Filter applied: None
// ************ Filter applied: Price above 30
// ************ Filter applied: Industry Cycle Up
// ************ Filter applied: Industry Cycle Down
// ************ Filter applied: Spy Short Term Up
// ************ Filter applied: Spy Short Term Down
// ************ Filter applied: Spy Long Term Up
// ************ Filter applied: Spy Long Term Down

// %%
// sort by ev and print the heck out of it
results
|> List.sortByDescending (fun ir -> ir.ev)
|> List.iter( fun ir -> 
    System.Console.WriteLine(ir.Describe())
)
// Out:
// EV : 41.29%	 Win: 75.16%, Avg Win: 68.77%, Avg Loss: -41.89%, total: 153, Industry Cycle Down: Buy Breakout 2-3
// EV : 37.23%	 Win: 66.15%, Avg Win: 72.37%, Avg Loss: -31.47%, total: 195, Spy Long Term Down: Buy Breakout 2-3
// EV : 37.17%	 Win: 66.93%, Avg Win: 72.53%, Avg Loss: -34.38%, total: 626, Spy Long Term Down: Buy Negative Price Slope
// EV : 33.74%	 Win: 65.56%, Avg Win: 68.48%, Avg Loss: -32.37%, total: 1141, Spy Long Term Down: Buy All
// EV : 33.40%	 Win: 69.29%, Avg Win: 62.97%, Avg Loss: -33.34%, total: 482, Industry Cycle Down: Buy Negative Price Slope
// EV : 29.56%	 Win: 63.88%, Avg Win: 63.32%, Avg Loss: -30.14%, total: 515, Spy Long Term Down: Buy Positive Price Slope
// EV : 29.42%	 Win: 67.74%, Avg Win: 58.87%, Avg Loss: -32.42%, total: 806, Industry Cycle Down: Buy All
// EV : 29.32%	 Win: 64.76%, Avg Win: 63.36%, Avg Loss: -33.26%, total: 403, Industry Cycle Up: Buy Negative Price Slope
// EV : 28.67%	 Win: 62.69%, Avg Win: 68.16%, Avg Loss: -37.68%, total: 193, Spy Short Term Up: Buy Breakout 2-3
// EV : 27.61%	 Win: 62.60%, Avg Win: 65.61%, Avg Loss: -36.01%, total: 730, Spy Short Term Down: Buy Negative Price Slope
// EV : 26.38%	 Win: 68.18%, Avg Win: 58.82%, Avg Loss: -43.11%, total: 22, Price above 30: Sell Breakout 4-5
// EV : 24.62%	 Win: 64.40%, Avg Win: 58.68%, Avg Loss: -37.02%, total: 368, Spy Short Term Up: Buy Negative Price Slope
L of 0.10% Breakout 4x+ & Price Angle <= -20 degrees
// EV : 8.98%	 Win: 26.03%, Avg Win: 98.14%, Avg Loss: -22.39%, total: 146, Spy Long Term Down: Buy SL of 0.20% Breakout 3-4
// EV : 8.88%	 Win: 73.17%, Avg Win: 44.66%, Avg Loss: -88.69%, total: 41, Spy Short Term Down: Sell Breakout 5+
// EV : 8.79%	 Win: 37.39%, Avg Win: 60.49%, Avg Loss: -22.09%, total: 1538, Industry Cycle Down: Buy SL of 0.20% Negative Price Slope
// EV : 8.73%	 Win: 32.46%, Avg Win: 73.37%, Avg Loss: -22.34%, total: 2686, Spy Long Term Down: Buy SL of 0.20% All
// EV : 8.56%	 Win: 56.36%, Avg Win: 48.74%, Avg Loss: -43.34%, total: 802, Price above 30: Buy Positive Price Slope
// EV : 8.54%	 Win: 33.09%, Avg Win: 70.50%, Avg Loss: -22.10%, total: 136, Spy Long Term Up: Buy SL of 0.20% Breakout 5+
// EV : 8.30%	 Win: 66.67%, Avg Win: 32.70%, Avg Loss: -40.51%, total: 18, Industry Cycle Down: Buy Breakout 4-5
// EV : 8.28%	 Win: 54.76%, Avg Win: 34.67%, Avg Loss: -23.66%, total: 42, Spy Long Term Up: Sell Breakout 5+
// EV : 8.25%	 Win: 66.00%, Avg Win: 23.51%, Avg Loss: -21.38%, total: 150, Spy Long Term Down: Sell hold for 60 bars Breakout 5+
// EV : 8.21%	 Win: 37.03%, Avg Win: 59.87%, Avg Loss: -22.17%, total: 2193, Industry Cycle Down: Buy SL of 0.20% All
// EV : 8.08%	 Win: 40.27%, Avg Win: 50.92%, Avg Loss: -20.80%, total: 1413, Industry Cycle Up: Buy SL of 0.20% Negative Price Slope
// EV : 8.03%	 Win: 53.33%, Avg Win: 31.05%, Avg Loss: -18.27%, total: 15, Industry Cycle Down: Sell Breakout 4x+ & Price Angle <= -20 degrees
// EV : 7.89%	 Win: 23.12%, Avg Win: 80.85%, Avg Loss: -14.05%, total: 199, Spy Short Term Up: Buy SL of 0.10% Breakout 5+
// EV : 7.84%	 Win: 33.78%, Avg Win: 65.94%, Avg Loss: -21.80%, total: 2229, Spy Short Term Down: Buy SL of 0.20% Negative Price Slope
// EV : 7.80%	 Win: 37.12%, Avg Win: 57.18%, Avg Loss: -21.36%, total: 2866, Price above 30: Buy SL of 0.20% All
// EV : 7.60%	 Win: 32.26%, Avg Win: 68.30%, Avg Loss: -21.31%, total: 1302, None: Buy SL of 0.20% Breakout 2-3
// EV : 7.50%	 Win: 32.02%, Avg Win: 70.44%, Avg Loss: -22.15%, total: 990, Spy Long Term Down: Buy SL of 0.20% Positive Price Slope
// EV : 7.20%	 Win: 33.63%, Avg Win: 64.51%, Avg Loss: -21.84%, total: 2878, Spy Short Term Down: Buy SL of 0.20% All
// EV : 7.19%	 Win: 24.10%, Avg Win: 67.83%, Avg Loss: -12.06%, total: 805, Price above 30: Buy SL of 0.10% Breakout 2-3
// EV : 6.92%	 Win: 27.38%, Avg Win: 58.82%, Avg Loss: -12.65%, total: 694, Industry Cycle Down: Buy SL of 0.10% Breakout 2-3
// EV : 6.88%	 Win: 39.09%, Avg Win: 50.22%, Avg Loss: -20.93%, total: 2781, Industry Cycle Up: Buy SL of 0.20% All
// EV : 6.85%	 Win: 36.18%, Avg Win: 58.36%, Avg Loss: -22.36%, total: 655, Industry Cycle Down: Buy SL of 0.20% Positive Price Slope
// EV : 6.66%	 Win: 25.11%, Avg Win: 63.10%, Avg Loss: -12.26%, total: 2712, Price above 30: Buy SL of 0.10% Negative Price Slope
// EV : 6.48%	 Win: 44.12%, Avg Win: 56.95%, Avg Loss: -33.37%, total: 34, Industry Cycle Down: Buy Breakout 3-4
// EV : 6.46%	 Win: 26.92%, Avg Win: 58.45%, Avg Loss: -12.68%, total: 2463, Industry Cycle Down: Buy SL of 0.10% Negative Price Slope
// EV : 6.44%	 Win: 25.47%, Avg Win: 87.61%, Avg Loss: -21.30%, total: 106, Industry Cycle Down: Buy SL of 0.20% Breakout 3-4
// EV : 6.34%	 Win: 66.67%, Avg Win: 41.86%, Avg Loss: -64.70%, total: 21, Price above 30: Sell Breakout 4x+ & Price Angle <= -20 degrees
// EV : 6.27%	 Win: 20.59%, Avg Win: 63.62%, Avg Loss: -8.61%, total: 238, Spy Long Term Up: Buy SL of 0.05% Breakout 5+
// EV : 6.26%	 Win: 20.43%, Avg Win: 80.91%, Avg Loss: -12.90%, total: 2589, Spy Long Term Down: Buy SL of 0.10% Negative Price Slope
// EV : 6.22%	 Win: 36.58%, Avg Win: 52.10%, Avg Loss: -20.24%, total: 503, Industry Cycle Up: Buy SL of 0.20% Breakout 2-3
// EV : 6.22%	 Win: 60.00%, Avg Win: 29.75%, Avg Loss: -29.09%, total: 25, Spy Short Term Up: Buy Breakout 4x+ & Price Angle <= -20 degrees
// EV : 5.93%	 Win: 15.94%, Avg Win: 82.28%, Avg Loss: -8.55%, total: 251, Industry Cycle Up: Buy SL of 0.05% Breakout 5+
// EV : 5.91%	 Win: 44.77%, Avg Win: 37.97%, Avg Loss: -20.08%, total: 1347, Spy Long Term Up: Buy SL of 0.20% Negative Price Slope
// EV : 5.90%	 Win: 39.71%, Avg Win: 48.00%, Avg Loss: -21.82%, total: 68, Spy Long Term Up: Buy SL of 0.20% Breakout 4x+ & Price Angle <= -20 degrees
// EV : 5.88%	 Win: 27.60%, Avg Win: 56.96%, Avg Loss: -13.59%, total: 192, Spy Long Term Up: Buy SL of 0.10% Breakout 5+
// EV : 5.88%	 Win: 38.10%, Avg Win: 52.56%, Avg Loss: -22.85%, total: 42, Spy Long Term Down: Sell SL of 0.20% Breakout 4-5
// EV : 5.84%	 Win: 46.15%, Avg Win: 42.50%, Avg Loss: -25.58%, total: 13, Spy Short Term Up: Sell Breakout 4-5
// EV : 5.77%	 Win: 31.11%, Avg Win: 67.25%, Avg Loss: -22.00%, total: 135, None: Buy SL of 0.20% Breakout 4x+ & Price Angle <= -20 degrees
// EV : 5.75%	 Win: 38.91%, Avg Win: 48.02%, Avg Loss: -21.17%, total: 1136, Price above 30: Buy SL of 0.20% Positive Price Slope
// EV : 5.63%	 Win: 37.87%, Avg Win: 49.44%, Avg Loss: -21.07%, total: 1368, Industry Cycle Up: Buy SL of 0.20% Positive Price Slope
// EV : 5.44%	 Win: 19.63%, Avg Win: 79.24%, Avg Loss: -12.59%, total: 764, Spy Long Term Down: Buy SL of 0.10% Breakout 2-3
// EV : 5.35%	 Win: 31.76%, Avg Win: 63.57%, Avg Loss: -21.75%, total: 4285, None: Buy SL of 0.20% Negative Price Slope
// EV : 5.27%	 Win: 27.70%, Avg Win: 51.67%, Avg Loss: -12.51%, total: 2404, Industry Cycle Up: Buy SL of 0.10% Negative Price Slope
// EV : 5.26%	 Win: 34.48%, Avg Win: 56.63%, Avg Loss: -21.78%, total: 116, Price above 30: Buy SL of 0.20% Breakout 3-4
// EV : 5.19%	 Win: 42.11%, Avg Win: 39.10%, Avg Loss: -19.47%, total: 76, Price above 30: Sell SL of 0.20% Breakout 4-5
// EV : 5.12%	 Win: 43.20%, Avg Win: 38.75%, Avg Loss: -20.47%, total: 2442, Spy Long Term Up: Buy SL of 0.20% All
// EV : 5.01%	 Win: 33.13%, Avg Win: 59.51%, Avg Loss: -21.98%, total: 649, Spy Short Term Down: Buy SL of 0.20% Positive Price Slope
// EV : 4.99%	 Win: 58.82%, Avg Win: 17.00%, Avg Loss: -12.16%, total: 51, Spy Short Term Down: Sell hold for 60 bars Breakout 4x+ & Price Angle <= -20 degrees
// EV : 4.98%	 Win: 37.25%, Avg Win: 49.62%, Avg Loss: -21.52%, total: 1608, Spy Short Term Up: Buy SL of 0.20% Positive Price Slope
// EV : 4.91%	 Win: 24.39%, Avg Win: 59.40%, Avg Loss: -12.66%, total: 3522, Spy Short Term Down: Buy SL of 0.10% Negative Price Slope
// EV : 4.91%	 Win: 61.16%, Avg Win: 17.64%, Avg Loss: -15.15%, total: 3249, Industry Cycle Down: Buy hold for 60 bars Negative Price Slope
// EV : 4.89%	 Win: 36.06%, Avg Win: 51.62%, Avg Loss: -21.47%, total: 513, Spy Short Term Up: Buy SL of 0.20% Breakout 2-3
// EV : 4.86%	 Win: 35.29%, Avg Win: 79.10%, Avg Loss: -35.63%, total: 17, Spy Short Term Down: Buy Breakout 4x+ & Price Angle <= -20 degrees
// EV : 4.86%	 Win: 32.39%, Avg Win: 60.33%, Avg Loss: -21.73%, total: 7097, None: Buy SL of 0.20% All
// EV : 4.85%	 Win: 40.31%, Avg Win: 42.23%, Avg Loss: -20.38%, total: 459, Spy Long Term Up: Buy SL of 0.20% Breakout 2-3
// EV : 4.79%	 Win: 31.88%, Avg Win: 42.78%, Avg Loss: -12.99%, total: 160, Price above 30: Sell SL of 0.10% Breakout 5+
// EV : 4.75%	 Win: 37.49%, Avg Win: 48.51%, Avg Loss: -21.49%, total: 2849, Spy Short Term Up: Buy SL of 0.20% All
// EV : 4.73%	 Win: 24.82%, Avg Win: 57.47%, Avg Loss: -12.69%, total: 3485, Industry Cycle Down: Buy SL of 0.10% All
// EV : 4.67%	 Win: 47.83%, Avg Win: 48.84%, Avg Loss: -35.81%, total: 46, Spy Long Term Down: Buy Breakout 3-4
// EV : 4.66%	 Win: 33.47%, Avg Win: 38.14%, Avg Loss: -12.18%, total: 2411, Spy Long Term Up: Buy SL of 0.10% Negative Price Slope
// EV : 4.59%	 Win: 20.18%, Avg Win: 73.44%, Avg Loss: -12.81%, total: 114, Spy Short Term Up: Buy SL of 0.10% Breakout 4x+ & Price Angle <= -20 degrees
// EV : 4.56%	 Win: 43.04%, Avg Win: 35.74%, Avg Loss: -19.00%, total: 79, Price above 30: Sell SL of 0.20% Breakout 4x+ & Price Angle <= -20 degrees
// EV : 4.56%	 Win: 60.92%, Avg Win: 15.71%, Avg Loss: -12.83%, total: 87, Price above 30: Sell hold for 60 bars Breakout 4x+ & Price Angle <= -20 degrees
// EV : 4.49%	 Win: 16.21%, Avg Win: 63.33%, Avg Loss: -6.89%, total: 1166, Price above 30: Buy SL of 0.05% Breakout 2-3
// EV : 4.46%	 Win: 37.79%, Avg Win: 47.10%, Avg Loss: -21.45%, total: 1241, Spy Short Term Up: Buy SL of 0.20% Negative Price Slope
// EV : 4.45%	 Win: 12.60%, Avg Win: 87.12%, Avg Loss: -7.47%, total: 127, Industry Cycle Up: Buy SL of 0.05% Breakout 4x+ & Price Angle <= -20 degrees
// EV : 4.44%	 Win: 21.76%, Avg Win: 65.55%, Avg Loss: -12.56%, total: 2054, None: Buy SL of 0.10% Breakout 2-3
// EV : 4.43%	 Win: 23.89%, Avg Win: 57.39%, Avg Loss: -12.19%, total: 4496, Price above 30: Buy SL of 0.10% All
// EV : 4.34%	 Win: 18.26%, Avg Win: 80.79%, Avg Loss: -12.75%, total: 4079, Spy Long Term Down: Buy SL of 0.10% All
// EV : 4.28%	 Win: 15.45%, Avg Win: 75.83%, Avg Loss: -8.79%, total: 246, Spy Short Term Up: Buy SL of 0.05% Breakout 5+
// EV : 4.27%	 Win: 9.09%, Avg Win: 180.80%, Avg Loss: -13.38%, total: 55, Spy Long Term Down: Buy SL of 0.10% Breakout 4x+ & Price Angle <= -20 degrees
// EV : 4.20%	 Win: 59.21%, Avg Win: 16.73%, Avg Loss: -13.98%, total: 4707, Spy Long Term Up: Buy hold for 60 bars Negative Price Slope
// EV : 4.17%	 Win: 61.76%, Avg Win: 16.13%, Avg Loss: -15.16%, total: 68, Spy Long Term Down: Sell hold for 60 bars Breakout 4x+ & Price Angle <= -20 degrees
// EV : 4.16%	 Win: 22.08%, Avg Win: 50.46%, Avg Loss: -8.96%, total: 317, Spy Long Term Up: Buy and use signal open as stop Breakout 5+
// EV : 4.15%	 Win: 41.28%, Avg Win: 39.80%, Avg Loss: -20.91%, total: 1095, Spy Long Term Up: Buy SL of 0.20% Positive Price Slope
// EV : 4.11%	 Win: 23.31%, Avg Win: 59.34%, Avg Loss: -12.67%, total: 4513, Spy Short Term Down: Buy SL of 0.10% All
// EV : 4.11%	 Win: 25.45%, Avg Win: 52.84%, Avg Loss: -12.52%, total: 2067, Spy Short Term Up: Buy SL of 0.10% Negative Price Slope
// EV : 4.11%	 Win: 22.50%, Avg Win: 61.48%, Avg Loss: -12.55%, total: 6630, None: Buy SL of 0.10% Negative Price Slope
// EV : 4.10%	 Win: 33.36%, Avg Win: 55.63%, Avg Loss: -21.69%, total: 2812, None: Buy SL of 0.20% Positive Price Slope
// EV : 4.05%	 Win: 31.08%, Avg Win: 40.87%, Avg Loss: -12.55%, total: 827, Spy Long Term Up: Buy SL of 0.10% Breakout 2-3
// EV : 3.98%	 Win: 54.84%, Avg Win: 19.98%, Avg Loss: -15.46%, total: 186, Price above 30: Sell hold for 60 bars Breakout 5+
// EV : 3.98%	 Win: 24.31%, Avg Win: 55.32%, Avg Loss: -12.52%, total: 872, Spy Short Term Down: Buy SL of 0.10% Breakout 2-3
// EV : 3.96%	 Win: 54.84%, Avg Win: 17.64%, Avg Loss: -12.65%, total: 124, Price above 30: Sell hold for 60 bars Breakout 4-5
// EV : 3.96%	 Win: 36.14%, Avg Win: 52.30%, Avg Loss: -23.41%, total: 166, Industry Cycle Up: Buy SL of 0.20% Breakout 3-4
// EV : 3.93%	 Win: 16.55%, Avg Win: 59.91%, Avg Loss: -7.17%, total: 3783, Price above 30: Buy SL of 0.05% Negative Price Slope
// EV : 3.89%	 Win: 53.72%, Avg Win: 22.78%, Avg Loss: -18.04%, total: 188, Spy Short Term Down: Sell hold for 60 bars Breakout 5+
// EV : 3.88%	 Win: 51.49%, Avg Win: 19.44%, Avg Loss: -12.63%, total: 101, Spy Long Term Down: Sell hold for 60 bars Breakout 4-5
// EV : 3.86%	 Win: 57.66%, Avg Win: 16.99%, Avg Loss: -14.02%, total: 1259, Spy Short Term Down: Buy hold for 60 bars Breakout 2-3
// EV : 3.83%	 Win: 26.27%, Avg Win: 49.60%, Avg Loss: -12.48%, total: 4591, Industry Cycle Up: Buy SL of 0.10% All
// EV : 3.81%	 Win: 20.41%, Avg Win: 48.30%, Avg Loss: -7.60%, total: 98, Industry Cycle Down: Sell SL of 0.05% Breakout 4-5
// EV : 3.78%	 Win: 16.99%, Avg Win: 58.29%, Avg Loss: -7.38%, total: 3384, Industry Cycle Down: Buy SL of 0.05% Negative Price Slope
// EV : 3.68%	 Win: 25.09%, Avg Win: 51.88%, Avg Loss: -12.47%, total: 861, Industry Cycle Up: Buy SL of 0.10% Breakout 2-3
// EV : 3.66%	 Win: 23.88%, Avg Win: 55.85%, Avg Loss: -12.72%, total: 871, Spy Short Term Up: Buy SL of 0.10% Breakout 2-3
// EV : 3.66%	 Win: 17.27%, Avg Win: 57.26%, Avg Loss: -7.53%, total: 961, Industry Cycle Down: Buy SL of 0.05% Breakout 2-3
// EV : 3.59%	 Win: 49.02%, Avg Win: 42.10%, Avg Loss: -33.44%, total: 51, Spy Short Term Up: Sell Breakout 5+
// EV : 3.59%	 Win: 54.35%, Avg Win: 44.27%, Avg Loss: -44.84%, total: 46, Industry Cycle Up: Buy Breakout 5+
// EV : 3.45%	 Win: 24.25%, Avg Win: 36.80%, Avg Loss: -7.23%, total: 3712, Spy Long Term Up: Buy SL of 0.05% Negative Price Slope
// EV : 3.44%	 Win: 20.02%, Avg Win: 46.78%, Avg Loss: -7.41%, total: 3477, Industry Cycle Up: Buy SL of 0.05% Negative Price Slope
// EV : 3.44%	 Win: 57.65%, Avg Win: 16.85%, Avg Loss: -14.82%, total: 1079, Industry Cycle Down: Buy hold for 60 bars Breakout 2-3
// EV : 3.41%	 Win: 40.91%, Avg Win: 35.58%, Avg Loss: -18.86%, total: 22, Spy Long Term Up: Sell Breakout 4x+ & Price Angle <= -20 degrees
// EV : 3.39%	 Win: 51.20%, Avg Win: 22.12%, Avg Loss: -16.26%, total: 209, Spy Long Term Down: Sell hold for 30 bars Breakout 5+
// EV : 3.35%	 Win: 31.60%, Avg Win: 37.38%, Avg Loss: -12.38%, total: 4231, Spy Long Term Up: Buy SL of 0.10% All
// EV : 3.31%	 Win: 51.69%, Avg Win: 13.84%, Avg Loss: -7.96%, total: 296, Spy Long Term Down: Sell hold for 10 bars Breakout 5+
// EV : 3.29%	 Win: 11.23%, Avg Win: 88.88%, Avg Loss: -7.54%, total: 3322, Spy Long Term Down: Buy SL of 0.05% Negative Price Slope
// EV : 3.27%	 Win: 55.83%, Avg Win: 16.35%, Avg Loss: -13.27%, total: 163, Industry Cycle Up: Sell hold for 60 bars Breakout 4-5
// EV : 3.19%	 Win: 54.83%, Avg Win: 17.65%, Avg Loss: -14.37%, total: 259, Spy Short Term Down: Sell hold for 30 bars Breakout 5+
// EV : 3.09%	 Win: 56.58%, Avg Win: 16.87%, Avg Loss: -14.86%, total: 5636, Industry Cycle Down: Buy hold for 60 bars All
// EV : 3.06%	 Win: 17.99%, Avg Win: 50.45%, Avg Loss: -7.33%, total: 3013, Spy Short Term Up: Buy SL of 0.05% Negative Price Slope
// EV : 3.06%	 Win: 56.70%, Avg Win: 17.05%, Avg Loss: -15.26%, total: 4467, Spy Short Term Down: Buy hold for 60 bars Negative Price Slope
// EV : 3.05%	 Win: 15.78%, Avg Win: 58.97%, Avg Loss: -7.42%, total: 4956, Industry Cycle Down: Buy SL of 0.05% All
// EV : 3.02%	 Win: 27.72%, Avg Win: 69.07%, Avg Loss: -22.31%, total: 386, None: Buy SL of 0.20% Breakout 3-4
// EV : 2.92%	 Win: 55.99%, Avg Win: 20.86%, Avg Loss: -19.92%, total: 534, None: Sell hold for 60 bars Breakout 5+
// EV : 2.90%	 Win: 16.11%, Avg Win: 56.67%, Avg Loss: -7.43%, total: 4742, Spy Short Term Down: Buy SL of 0.05% Negative Price Slope
// EV : 2.87%	 Win: 15.39%, Avg Win: 59.24%, Avg Loss: -7.38%, total: 8947, None: Buy SL of 0.05% Negative Price Slope
// EV : 2.84%	 Win: 29.88%, Avg Win: 26.96%, Avg Loss: -7.43%, total: 164, Industry Cycle Down: Sell hold for 60 bars SL of 0.05% Breakout 4-5
// EV : 2.82%	 Win: 51.75%, Avg Win: 18.40%, Avg Loss: -13.89%, total: 228, Industry Cycle Down: Sell hold for 30 bars Breakout 5+
// EV : 2.80%	 Win: 25.71%, Avg Win: 31.78%, Avg Loss: -7.24%, total: 140, Price above 30: Sell SL of 0.05% Breakout 4x+ & Price Angle <= -20 degrees
// EV : 2.79%	 Win: 15.76%, Avg Win: 57.63%, Avg Loss: -7.47%, total: 6213, Spy Short Term Down: Buy SL of 0.05% All
// EV : 2.78%	 Win: 40.93%, Avg Win: 17.36%, Avg Loss: -7.32%, total: 193, Industry Cycle Down: Sell hold for 30 bars SL of 0.05% Breakout 4-5
// EV : 2.77%	 Win: 14.71%, Avg Win: 50.12%, Avg Loss: -5.40%, total: 1203, Industry Cycle Down: Buy and use signal open as stop Breakout 2-3
// EV : 2.77%	 Win: 14.91%, Avg Win: 60.65%, Avg Loss: -7.38%, total: 2823, None: Buy SL of 0.05% Breakout 2-3
// EV : 2.75%	 Win: 56.93%, Avg Win: 9.35%, Avg Loss: -5.97%, total: 137, Industry Cycle Down: Sell hold for 10 bars Breakout 4x+ & Price Angle <= -20 degrees
// EV : 2.74%	 Win: 54.40%, Avg Win: 15.73%, Avg Loss: -12.77%, total: 250, Price above 30: Sell hold for 30 bars Breakout 5+
// EV : 2.70%	 Win: 55.93%, Avg Win: 16.34%, Avg Loss: -14.61%, total: 6481, Spy Short Term Down: Buy hold for 60 bars All
// EV : 2.70%	 Win: 33.33%, Avg Win: 31.78%, Avg Loss: -11.85%, total: 108, Price above 30: Sell SL of 0.10% Breakout 4x+ & Price Angle <= -20 degrees
// EV : 2.69%	 Win: 49.07%, Avg Win: 15.82%, Avg Loss: -9.97%, total: 108, Industry Cycle Down: Sell and use trailing stop, SL of 0.1% Breakout 4x+ & Price Angle <= -20 degrees
// EV : 2.68%	 Win: 21.45%, Avg Win: 58.48%, Avg Loss: -12.55%, total: 10824, None: Buy SL of 0.10% All
// EV : 2.67%	 Win: 15.79%, Avg Win: 54.52%, Avg Loss: -7.04%, total: 6582, Price above 30: Buy SL of 0.05% All
// EV : 2.64%	 Win: 60.53%, Avg Win: 8.31%, Avg Loss: -6.07%, total: 228, Industry Cycle Down: Sell hold for 10 bars Breakout 4-5
// EV : 2.62%	 Win: 59.15%, Avg Win: 19.34%, Avg Loss: -21.58%, total: 284, Spy Short Term Up: Sell hold for 60 bars Breakout 5+
// EV : 2.62%	 Win: 22.26%, Avg Win: 37.33%, Avg Loss: -7.32%, total: 1231, Spy Long Term Up: Buy SL of 0.05% Breakout 2-3
// EV : 2.61%	 Win: 52.71%, Avg Win: 18.32%, Avg Loss: -14.90%, total: 129, Spy Short Term Down: Sell hold for 60 bars Breakout 4-5
// EV : 2.56%	 Win: 10.44%, Avg Win: 74.43%, Avg Loss: -5.81%, total: 3784, Spy Long Term Down: Buy and use signal open as stop Negative Price Slope
// EV : 2.56%	 Win: 16.72%, Avg Win: 61.99%, Avg Loss: -9.37%, total: 311, Industry Cycle Up: Buy and use signal open as stop Breakout 5+
// EV : 2.55%	 Win: 55.58%, Avg Win: 13.49%, Avg Loss: -11.14%, total: 1819, Spy Short Term Down: Buy hold for 30 bars Breakout 2-3
// EV : 2.50%	 Win: 50.00%, Avg Win: 24.09%, Avg Loss: -19.09%, total: 166, Industry Cycle Down: Sell hold for 60 bars Breakout 5+
// EV : 2.48%	 Win: 16.43%, Avg Win: 52.94%, Avg Loss: -7.44%, total: 1205, Spy Short Term Down: Buy SL of 0.05% Breakout 2-3
// EV : 2.47%	 Win: 19.58%, Avg Win: 43.26%, Avg Loss: -7.46%, total: 143, Industry Cycle Up: Buy SL of 0.05% Breakout 4-5
// EV : 2.47%	 Win: 54.44%, Avg Win: 16.46%, Avg Loss: -14.24%, total: 3909, Industry Cycle Up: Buy hold for 60 bars Negative Price Slope
// EV : 2.45%	 Win: 14.62%, Avg Win: 61.03%, Avg Loss: -7.57%, total: 1471, Spy Short Term Down: Buy SL of 0.05% Positive Price Slope
// EV : 2.45%	 Win: 13.76%, Avg Win: 98.54%, Avg Loss: -12.88%, total: 218, Spy Long Term Down: Buy SL of 0.10% Breakout 3-4
// EV : 2.44%	 Win: 52.69%, Avg Win: 17.68%, Avg Loss: -14.54%, total: 334, None: Sell hold for 60 bars Breakout 4-5
// EV : 2.42%	 Win: 47.76%, Avg Win: 20.21%, Avg Loss: -13.84%, total: 67, Industry Cycle Down: Sell hold for 60 bars Breakout 4x+ & Price Angle <= -20 degrees
// EV : 2.41%	 Win: 17.98%, Avg Win: 73.78%, Avg Loss: -13.24%, total: 89, Spy Short Term Down: Buy SL of 0.10% Breakout 4-5
// EV : 2.40%	 Win: 22.32%, Avg Win: 35.99%, Avg Loss: -7.25%, total: 6529, Spy Long Term Up: Buy SL of 0.05% All
// EV : 2.38%	 Win: 50.00%, Avg Win: 51.88%, Avg Loss: -47.13%, total: 14, Industry Cycle Up: Buy Breakout 4-5
// EV : 2.37%	 Win: 54.39%, Avg Win: 16.08%, Avg Loss: -13.97%, total: 9791, Spy Long Term Up: Buy hold for 60 bars All
// EV : 2.36%	 Win: 41.92%, Avg Win: 14.72%, Avg Loss: -6.57%, total: 291, Industry Cycle Up: Buy hold for 30 bars SL of 0.05% Breakout 4-5
// EV : 2.35%	 Win: 10.22%, Avg Win: 88.67%, Avg Loss: -7.48%, total: 5439, Spy Long Term Down: Buy SL of 0.05% All
// EV : 2.33%	 Win: 17.14%, Avg Win: 33.09%, Avg Loss: -4.04%, total: 420, Industry Cycle Up: Buy and use signal close as stop Breakout 5+
// EV : 2.31%	 Win: 32.80%, Avg Win: 20.28%, Avg Loss: -6.46%, total: 186, Price above 30: Sell hold for 60 bars SL of 0.05% Breakout 4-5
// EV : 2.30%	 Win: 38.46%, Avg Win: 38.17%, Avg Loss: -20.11%, total: 13, Spy Long Term Up: Sell Breakout 4-5
// EV : 2.30%	 Win: 13.86%, Avg Win: 46.15%, Avg Loss: -4.76%, total: 4814, Price above 30: Buy and use signal open as stop Negative Price Slope
// EV : 2.29%	 Win: 18.32%, Avg Win: 45.09%, Avg Loss: -7.31%, total: 6698, Industry Cycle Up: Buy SL of 0.05% All
// EV : 2.29%	 Win: 43.60%, Avg Win: 16.62%, Avg Loss: -8.80%, total: 6667, Spy Long Term Up: Buy and use trailing stop, SL of 0.1% Negative Price Slope
// EV : 2.28%	 Win: 11.00%, Avg Win: 80.66%, Avg Loss: -7.41%, total: 1027, Spy Long Term Down: Buy SL of 0.05% Breakout 2-3
// EV : 2.27%	 Win: 42.72%, Avg Win: 21.94%, Avg Loss: -12.40%, total: 4033, Industry Cycle Down: Buy SL of 0.10% PT of 0.20% Negative Price Slope
// EV : 2.27%	 Win: 23.95%, Avg Win: 49.29%, Avg Loss: -12.54%, total: 4610, Spy Short Term Up: Buy SL of 0.10% All
// EV : 2.25%	 Win: 52.00%, Avg Win: 10.71%, Avg Loss: -6.93%, total: 300, Spy Long Term Down: Sell hold for 5 bars Breakout 5+
// EV : 2.25%	 Win: 45.76%, Avg Win: 18.74%, Avg Loss: -11.67%, total: 5184, Spy Long Term Up: Buy SL of 0.10% PT of 0.20% Negative Price Slope
// EV : 2.24%	 Win: 24.69%, Avg Win: 47.04%, Avg Loss: -12.45%, total: 2187, Industry Cycle Up: Buy SL of 0.10% Positive Price Slope
// EV : 2.24%	 Win: 26.67%, Avg Win: 43.35%, Avg Loss: -12.71%, total: 60, Spy Long Term Down: Sell SL of 0.10% Breakout 4-5
// EV : 2.22%	 Win: 41.55%, Avg Win: 15.72%, Avg Loss: -7.37%, total: 207, Spy Short Term Down: Sell hold for 30 bars SL of 0.05% Breakout 4-5
// EV : 2.22%	 Win: 44.60%, Avg Win: 20.47%, Avg Loss: -12.47%, total: 361, Industry Cycle Up: Buy SL of 0.10% PT of 0.20% Breakout 5+
// EV : 2.22%	 Win: 44.06%, Avg Win: 20.37%, Avg Loss: -12.07%, total: 1464, Spy Short Term Down: Buy SL of 0.10% PT of 0.20% Breakout 2-3
// EV : 2.22%	 Win: 17.46%, Avg Win: 57.38%, Avg Loss: -9.45%, total: 315, Spy Short Term Up: Buy and use signal open as stop Breakout 5+
// EV : 2.21%	 Win: 46.30%, Avg Win: 15.46%, Avg Loss: -9.22%, total: 162, Industry Cycle Down: Sell and use trailing stop, SL of 0.1% Breakout 4-5
// EV : 2.20%	 Win: 43.69%, Avg Win: 20.62%, Avg Loss: -12.10%, total: 5548, Spy Short Term Down: Buy SL of 0.10% PT of 0.20% Negative Price Slope
// EV : 2.18%	 Win: 48.28%, Avg Win: 13.25%, Avg Loss: -8.15%, total: 116, Industry Cycle Down: Sell SL of 0.05% PT of 0.10% Breakout 4x+ & Price Angle <= -20 degrees
// EV : 2.17%	 Win: 54.43%, Avg Win: 14.09%, Avg Loss: -12.07%, total: 4722, Industry Cycle Down: Buy hold for 30 bars Negative Price Slope
// EV : 2.13%	 Win: 15.85%, Avg Win: 43.43%, Avg Loss: -5.64%, total: 1464, Spy Short Term Down: Buy and use signal open as stop Breakout 2-3
// EV : 2.12%	 Win: 53.40%, Avg Win: 12.66%, Avg Loss: -9.96%, total: 191, Price above 30: Sell hold for 30 bars Breakout 4-5
// EV : 2.11%	 Win: 13.98%, Avg Win: 46.57%, Avg Loss: -5.11%, total: 4083, Industry Cycle Down: Buy and use signal open as stop Negative Price Slope
// EV : 2.10%	 Win: 54.66%, Avg Win: 15.12%, Avg Loss: -13.58%, total: 1910, Spy Long Term Up: Buy hold for 60 bars Breakout 2-3
// EV : 2.10%	 Win: 53.82%, Avg Win: 13.70%, Avg Loss: -11.42%, total: 6514, Spy Short Term Down: Buy hold for 30 bars Negative Price Slope
// EV : 2.07%	 Win: 55.07%, Avg Win: 7.12%, Avg Loss: -4.11%, total: 138, Industry Cycle Down: Sell hold for 5 bars Breakout 4x+ & Price Angle <= -20 degrees
// EV : 2.06%	 Win: 55.60%, Avg Win: 16.80%, Avg Loss: -16.39%, total: 268, None: Sell hold for 60 bars Breakout 4x+ & Price Angle <= -20 degrees
// EV : 2.05%	 Win: 57.93%, Avg Win: 11.37%, Avg Loss: -10.79%, total: 145, Price above 30: Sell hold for 30 bars Breakout 4x+ & Price Angle <= -20 degrees
// EV : 2.04%	 Win: 18.98%, Avg Win: 24.07%, Avg Loss: -3.13%, total: 511, Spy Short Term Down: Buy and use signal close as stop Breakout 3-4
// EV : 2.04%	 Win: 13.77%, Avg Win: 46.57%, Avg Loss: -5.07%, total: 2041, Spy Short Term Down: Buy and use signal open as stop Positive Price Slope
// EV : 2.03%	 Win: 21.18%, Avg Win: 40.44%, Avg Loss: -8.29%, total: 203, Price above 30: Sell SL of 0.05% Breakout 5+
// EV : 2.02%	 Win: 35.46%, Avg Win: 18.24%, Avg Loss: -6.89%, total: 7310, Spy Long Term Up: Buy hold for 60 bars SL of 0.05% Negative Price Slope
// EV : 2.02%	 Win: 38.02%, Avg Win: 16.28%, Avg Loss: -6.72%, total: 121, Industry Cycle Down: Sell hold for 30 bars SL of 0.05% Breakout 4x+ & Price Angle <= -20 degrees
// EV : 2.01%	 Win: 41.31%, Avg Win: 17.94%, Avg Loss: -9.20%, total: 4980, Industry Cycle Down: Buy and use trailing stop, SL of 0.1% Negative Price Slope
// EV : 2.01%	 Win: 10.04%, Avg Win: 71.42%, Avg Loss: -5.73%, total: 1235, Spy Long Term Down: Buy and use signal open as stop Breakout 2-3
// EV : 1.99%	 Win: 52.07%, Avg Win: 17.28%, Avg Loss: -14.62%, total: 169, Spy Short Term Up: Sell hold for 60 bars Breakout 4-5
// EV : 1.95%	 Win: 17.37%, Avg Win: 36.80%, Avg Loss: -5.37%, total: 4376, Industry Cycle Up: Buy and use signal open as stop Negative Price Slope
// EV : 1.95%	 Win: 53.94%, Avg Win: 11.54%, Avg Loss: -9.29%, total: 343, Spy Short Term Down: Sell hold for 10 bars Breakout 5+
// EV : 1.94%	 Win: 38.89%, Avg Win: 15.78%, Avg Loss: -6.86%, total: 90, Spy Short Term Down: Sell hold for 30 bars SL of 0.05% Breakout 4x+ & Price Angle <= -20 degrees
// EV : 1.94%	 Win: 17.75%, Avg Win: 44.51%, Avg Loss: -7.25%, total: 1245, Industry Cycle Up: Buy SL of 0.05% Breakout 2-3
// EV : 1.93%	 Win: 14.96%, Avg Win: 84.06%, Avg Loss: -12.52%, total: 234, Spy Short Term Down: Buy SL of 0.10% Breakout 3-4
// EV : 1.92%	 Win: 15.82%, Avg Win: 49.14%, Avg Loss: -6.95%, total: 177, Industry Cycle Up: Buy and use signal open as stop Breakout 4-5
// EV : 1.91%	 Win: 14.52%, Avg Win: 44.56%, Avg Loss: -5.33%, total: 7721, Spy Short Term Down: Buy and use signal open as stop All
// EV : 1.91%	 Win: 43.16%, Avg Win: 20.40%, Avg Loss: -12.13%, total: 7688, Spy Short Term Down: Buy SL of 0.10% PT of 0.20% All
// EV : 1.90%	 Win: 53.71%, Avg Win: 17.33%, Avg Loss: -16.00%, total: 8686, None: Buy hold for 60 bars Negative Price Slope
// EV : 1.90%	 Win: 16.67%, Avg Win: 31.65%, Avg Loss: -4.05%, total: 420, Spy Short Term Up: Buy and use signal close as stop Breakout 5+
// EV : 1.90%	 Win: 54.22%, Avg Win: 14.68%, Avg Loss: -13.25%, total: 2014, Spy Short Term Down: Buy hold for 60 bars Positive Price Slope
// EV : 1.89%	 Win: 14.49%, Avg Win: 56.45%, Avg Loss: -7.36%, total: 15000, None: Buy SL of 0.05% All
// EV : 1.89%	 Win: 20.25%, Avg Win: 64.69%, Avg Loss: -14.06%, total: 79, Industry Cycle Down: Buy SL of 0.10% Breakout 4-5
// EV : 1.89%	 Win: 43.16%, Avg Win: 16.02%, Avg Loss: -8.84%, total: 6831, Spy Short Term Down: Buy and use trailing stop, SL of 0.1% Negative Price Slope
// EV : 1.88%	 Win: 56.15%, Avg Win: 9.14%, Avg Loss: -7.41%, total: 301, Industry Cycle Down: Sell hold for 5 bars Breakout 5+
// EV : 1.88%	 Win: 40.98%, Avg Win: 36.83%, Avg Loss: -22.39%, total: 61, Spy Long Term Up: Buy SL of 0.20% Breakout 4-5
// EV : 1.87%	 Win: 14.79%, Avg Win: 43.89%, Avg Loss: -5.42%, total: 5680, Spy Short Term Down: Buy and use signal open as stop Negative Price Slope
// EV : 1.87%	 Win: 14.29%, Avg Win: 61.21%, Avg Loss: -8.02%, total: 112, Spy Long Term Up: Buy SL of 0.05% Breakout 4x+ & Price Angle <= -20 degrees
// EV : 1.86%	 Win: 57.14%, Avg Win: 33.41%, Avg Loss: -40.21%, total: 42, Industry Cycle Up: Buy Breakout 3-4
// EV : 1.86%	 Win: 41.63%, Avg Win: 21.49%, Avg Loss: -12.14%, total: 418, Spy Short Term Down: Buy SL of 0.10% PT of 0.20% Breakout 3-4
// EV : 1.85%	 Win: 19.31%, Avg Win: 29.45%, Avg Loss: -4.75%, total: 4874, Spy Long Term Up: Buy and use signal open as stop Negative Price Slope
// EV : 1.84%	 Win: 42.66%, Avg Win: 20.21%, Avg Loss: -11.83%, total: 4728, Price above 30: Buy SL of 0.10% PT of 0.20% Negative Price Slope
// EV : 1.80%	 Win: 40.61%, Avg Win: 22.44%, Avg Loss: -12.31%, total: 1236, Industry Cycle Down: Buy SL of 0.10% PT of 0.20% Breakout 2-3
// EV : 1.79%	 Win: 55.41%, Avg Win: 12.55%, Avg Loss: -11.57%, total: 74, Spy Short Term Down: Sell hold for 30 bars Breakout 4x+ & Price Angle <= -20 degrees
// EV : 1.79%	 Win: 44.33%, Avg Win: 18.69%, Avg Loss: -11.67%, total: 4462, Industry Cycle Up: Buy SL of 0.10% PT of 0.20% Negative Price Slope
// EV : 1.76%	 Win: 57.39%, Avg Win: 14.95%, Avg Loss: -16.01%, total: 345, Spy Short Term Down: Buy hold for 60 bars Breakout 3-4
// EV : 1.74%	 Win: 53.44%, Avg Win: 13.05%, Avg Loss: -11.25%, total: 9481, Spy Short Term Down: Buy hold for 30 bars All
// EV : 1.73%	 Win: 55.17%, Avg Win: 15.11%, Avg Loss: -14.75%, total: 4247, Price above 30: Buy hold for 60 bars Negative Price Slope
// EV : 1.72%	 Win: 12.36%, Avg Win: 63.62%, Avg Loss: -7.01%, total: 178, Industry Cycle Up: Buy and use signal open as stop Breakout 4x+ & Price Angle <= -20 degrees
// EV : 1.71%	 Win: 30.98%, Avg Win: 23.55%, Avg Loss: -8.09%, total: 255, Spy Long Term Down: Sell hold for 30 bars SL of 0.05% Breakout 5+
// EV : 1.70%	 Win: 38.46%, Avg Win: 39.03%, Avg Loss: -21.64%, total: 52, Spy Short Term Down: Sell SL of 0.20% Breakout 4-5
// EV : 1.68%	 Win: 13.22%, Avg Win: 46.06%, Avg Loss: -5.08%, total: 6308, Industry Cycle Down: Buy and use signal open as stop All
// EV : 1.68%	 Win: 56.69%, Avg Win: 12.25%, Avg Loss: -12.15%, total: 3341, Spy Long Term Down: Sell hold for 30 bars Positive Price Slope
// EV : 1.68%	 Win: 18.95%, Avg Win: 41.29%, Avg Loss: -7.59%, total: 95, Price above 30: Buy SL of 0.05% Breakout 4-5
// EV : 1.66%	 Win: 51.57%, Avg Win: 16.80%, Avg Loss: -14.46%, total: 508, Spy Short Term Up: Sell hold for 60 bars Breakout 3-4
// EV : 1.66%	 Win: 15.95%, Avg Win: 49.14%, Avg Loss: -7.35%, total: 1248, Spy Short Term Up: Buy SL of 0.05% Breakout 2-3
// EV : 1.66%	 Win: 18.41%, Avg Win: 22.88%, Avg Loss: -3.13%, total: 440, Industry Cycle Down: Buy and use signal close as stop Breakout 3-4
// EV : 1.66%	 Win: 14.48%, Avg Win: 42.09%, Avg Loss: -5.19%, total: 3772, Spy Short Term Up: Buy and use signal open as stop Negative Price Slope
// EV : 1.65%	 Win: 43.64%, Avg Win: 15.15%, Avg Loss: -8.80%, total: 1723, Spy Short Term Down: Buy and use trailing stop, SL of 0.1% Breakout 2-3
// EV : 1.64%	 Win: 32.17%, Avg Win: 21.07%, Avg Loss: -7.57%, total: 115, Industry Cycle Down: Sell hold for 60 bars SL of 0.05% Breakout 4x+ & Price Angle <= -20 degrees
// EV : 1.64%	 Win: 52.97%, Avg Win: 12.64%, Avg Loss: -10.75%, total: 6887, Spy Long Term Up: Buy hold for 30 bars Negative Price Slope
// EV : 1.64%	 Win: 18.58%, Avg Win: 21.33%, Avg Loss: -2.86%, total: 1868, Spy Short Term Down: Buy and use signal close as stop Breakout 2-3
// EV : 1.63%	 Win: 51.36%, Avg Win: 12.58%, Avg Loss: -9.93%, total: 294, Industry Cycle Down: Sell hold for 10 bars Breakout 5+
// EV : 1.61%	 Win: 43.33%, Avg Win: 19.82%, Avg Loss: -12.31%, total: 390, Spy Long Term Up: Buy SL of 0.10% PT of 0.20% Breakout 5+
// EV : 1.61%	 Win: 52.72%, Avg Win: 9.49%, Avg Loss: -7.18%, total: 349, Spy Short Term Down: Sell hold for 5 bars Breakout 5+
// EV : 1.60%	 Win: 22.73%, Avg Win: 51.58%, Avg Loss: -13.09%, total: 88, Spy Long Term Up: Buy SL of 0.10% Breakout 4x+ & Price Angle <= -20 degrees
// EV : 1.60%	 Win: 29.12%, Avg Win: 36.23%, Avg Loss: -12.63%, total: 1820, Spy Long Term Up: Buy SL of 0.10% Positive Price Slope
// EV : 1.59%	 Win: 43.89%, Avg Win: 18.59%, Avg Loss: -11.71%, total: 10326, Spy Long Term Up: Buy SL of 0.10% PT of 0.20% All
// EV : 1.59%	 Win: 53.02%, Avg Win: 12.31%, Avg Loss: -10.51%, total: 5619, Industry Cycle Up: Buy hold for 30 bars Negative Price Slope
// EV : 1.58%	 Win: 58.46%, Avg Win: 17.85%, Avg Loss: -21.30%, total: 272, Industry Cycle Up: Sell hold for 60 bars Breakout 5+
// EV : 1.58%	 Win: 45.45%, Avg Win: 15.01%, Avg Loss: -9.61%, total: 165, Spy Short Term Down: Sell and use trailing stop, SL of 0.1% Breakout 4-5
// EV : 1.58%	 Win: 52.44%, Avg Win: 17.62%, Avg Loss: -16.12%, total: 2559, Spy Long Term Down: Buy hold for 60 bars Negative Price Slope
// EV : 1.57%	 Win: 41.30%, Avg Win: 16.34%, Avg Loss: -8.83%, total: 11225, Spy Long Term Up: Buy and use trailing stop, SL of 0.1% All
// EV : 1.57%	 Win: 25.00%, Avg Win: 48.03%, Avg Loss: -13.92%, total: 244, Industry Cycle Up: Buy SL of 0.10% Breakout 3-4
// EV : 1.56%	 Win: 13.04%, Avg Win: 42.14%, Avg Loss: -4.52%, total: 8991, Price above 30: Buy and use signal open as stop All
// EV : 1.56%	 Win: 35.59%, Avg Win: 15.65%, Avg Loss: -6.23%, total: 222, Price above 30: Sell hold for 30 bars SL of 0.05% Breakout 4-5
// EV : 1.56%	 Win: 52.11%, Avg Win: 10.11%, Avg Loss: -7.75%, total: 332, Price above 30: Sell hold for 10 bars Breakout 5+
// EV : 1.55%	 Win: 21.43%, Avg Win: 58.63%, Avg Loss: -14.02%, total: 112, Spy Long Term Down: Sell SL of 0.10% Breakout 5+
// EV : 1.54%	 Win: 30.89%, Avg Win: 20.75%, Avg Loss: -7.04%, total: 5286, Industry Cycle Down: Buy hold for 60 bars SL of 0.05% Negative Price Slope
// EV : 1.54%	 Win: 13.76%, Avg Win: 44.84%, Avg Loss: -5.36%, total: 10780, None: Buy and use signal open as stop Negative Price Slope
// EV : 1.54%	 Win: 13.01%, Avg Win: 61.79%, Avg Loss: -7.47%, total: 146, Spy Short Term Up: Buy SL of 0.05% Breakout 4x+ & Price Angle <= -20 degrees
// EV : 1.54%	 Win: 50.88%, Avg Win: 17.21%, Avg Loss: -14.70%, total: 967, Spy Long Term Down: Buy hold for 60 bars Breakout 2-3
// EV : 1.54%	 Win: 49.29%, Avg Win: 15.22%, Avg Loss: -11.77%, total: 422, Price above 30: Sell hold for 60 bars Breakout 3-4
// EV : 1.53%	 Win: 58.15%, Avg Win: 7.12%, Avg Loss: -6.24%, total: 4726, Industry Cycle Down: Sell hold for 10 bars Positive Price Slope
// EV : 1.53%	 Win: 42.17%, Avg Win: 15.78%, Avg Loss: -8.87%, total: 9091, Spy Short Term Down: Buy and use trailing stop, SL of 0.1% All
// EV : 1.52%	 Win: 57.51%, Avg Win: 6.37%, Avg Loss: -5.06%, total: 233, Industry Cycle Down: Sell hold for 5 bars Breakout 4-5
// EV : 1.51%	 Win: 14.96%, Avg Win: 45.16%, Avg Loss: -6.16%, total: 127, Price above 30: Buy and use signal open as stop Breakout 4-5
// EV : 1.50%	 Win: 36.67%, Avg Win: 17.71%, Avg Loss: -7.88%, total: 300, Spy Short Term Down: Sell hold for 30 bars SL of 0.05% Breakout 5+
// EV : 1.50%	 Win: 23.94%, Avg Win: 45.48%, Avg Loss: -12.34%, total: 71, Industry Cycle Down: Sell SL of 0.10% Breakout 4-5
// EV : 1.50%	 Win: 9.24%, Avg Win: 70.68%, Avg Loss: -5.54%, total: 6528, Spy Long Term Down: Buy and use signal open as stop All
// EV : 1.50%	 Win: 17.59%, Avg Win: 20.34%, Avg Loss: -2.52%, total: 6167, Price above 30: Buy and use signal close as stop Negative Price Slope
// EV : 1.50%	 Win: 17.47%, Avg Win: 70.17%, Avg Loss: -13.04%, total: 229, None: Buy SL of 0.10% Breakout 4-5
// EV : 1.50%	 Win: 13.17%, Avg Win: 60.86%, Avg Loss: -7.51%, total: 1572, Industry Cycle Down: Buy SL of 0.05% Positive Price Slope
// EV : 1.50%	 Win: 15.82%, Avg Win: 79.63%, Avg Loss: -13.19%, total: 177, None: Buy SL of 0.10% Breakout 4x+ & Price Angle <= -20 degrees
// EV : 1.49%	 Win: 57.87%, Avg Win: 7.40%, Avg Loss: -6.61%, total: 4743, Spy Long Term Down: Sell hold for 10 bars Positive Price Slope
// EV : 1.49%	 Win: 38.93%, Avg Win: 15.68%, Avg Loss: -7.55%, total: 447, Industry Cycle Up: Buy hold for 30 bars SL of 0.05% Breakout 5+
// EV : 1.47%	 Win: 53.29%, Avg Win: 13.95%, Avg Loss: -12.76%, total: 3629, Spy Long Term Down: Buy hold for 30 bars Negative Price Slope
// EV : 1.47%	 Win: 19.19%, Avg Win: 29.95%, Avg Loss: -5.29%, total: 1699, Spy Long Term Up: Buy and use signal open as stop Breakout 2-3
// EV : 1.47%	 Win: 29.85%, Avg Win: 23.34%, Avg Loss: -7.84%, total: 392, Spy Long Term Up: Buy hold for 60 bars SL of 0.05% Breakout 5+
// EV : 1.45%	 Win: 42.42%, Avg Win: 62.95%, Avg Loss: -43.86%, total: 66, None: Buy Breakout 4-5
// EV : 1.45%	 Win: 46.46%, Avg Win: 8.49%, Avg Loss: -4.66%, total: 99, Spy Short Term Down: Sell hold for 5 bars Breakout 4x+ & Price Angle <= -20 degrees
// EV : 1.45%	 Win: 43.94%, Avg Win: 12.69%, Avg Loss: -7.37%, total: 198, Industry Cycle Down: Sell SL of 0.05% PT of 0.10% Breakout 4-5
// EV : 1.43%	 Win: 18.40%, Avg Win: 19.61%, Avg Loss: -2.67%, total: 2946, Spy Short Term Down: Buy and use signal close as stop Positive Price Slope
// EV : 1.41%	 Win: 13.53%, Avg Win: 40.74%, Avg Loss: -4.74%, total: 1597, Price above 30: Buy and use signal open as stop Breakout 2-3
// EV : 1.40%	 Win: 41.14%, Avg Win: 20.70%, Avg Loss: -12.09%, total: 10510, None: Buy SL of 0.10% PT of 0.20% Negative Price Slope
// EV : 1.39%	 Win: 49.45%, Avg Win: 13.48%, Avg Loss: -10.43%, total: 91, Industry Cycle Down: Sell hold for 30 bars Breakout 4x+ & Price Angle <= -20 degrees
// EV : 1.39%	 Win: 33.62%, Avg Win: 17.71%, Avg Loss: -6.88%, total: 13228, Spy Long Term Up: Buy hold for 60 bars SL of 0.05% All
// EV : 1.39%	 Win: 16.00%, Avg Win: 46.89%, Avg Loss: -7.28%, total: 6775, Spy Short Term Up: Buy SL of 0.05% All
// EV : 1.38%	 Win: 38.39%, Avg Win: 14.47%, Avg Loss: -6.77%, total: 310, Spy Short Term Up: Buy hold for 30 bars SL of 0.05% Breakout 4-5
// EV : 1.38%	 Win: 15.98%, Avg Win: 25.10%, Avg Loss: -3.13%, total: 4369, Spy Long Term Down: Buy and use signal close as stop Negative Price Slope
// EV : 1.38%	 Win: 35.16%, Avg Win: 19.12%, Avg Loss: -8.24%, total: 256, Industry Cycle Down: Sell hold for 30 bars SL of 0.05% Breakout 5+
// EV : 1.38%	 Win: 47.50%, Avg Win: 15.13%, Avg Loss: -11.07%, total: 80, Spy Short Term Down: Sell and use trailing stop, SL of 0.1% Breakout 4x+ & Price Angle <= -20 degrees
// EV : 1.37%	 Win: 32.63%, Avg Win: 29.00%, Avg Loss: -12.02%, total: 95, Price above 30: Sell SL of 0.10% Breakout 4-5
// EV : 1.36%	 Win: 40.16%, Avg Win: 21.82%, Avg Loss: -12.37%, total: 6451, Industry Cycle Down: Buy SL of 0.10% PT of 0.20% All
// EV : 1.36%	 Win: 37.27%, Avg Win: 14.70%, Avg Loss: -6.57%, total: 330, Spy Long Term Up: Buy hold for 30 bars SL of 0.05% Breakout 4-5
// EV : 1.36%	 Win: 44.21%, Avg Win: 12.18%, Avg Loss: -7.22%, total: 484, Industry Cycle Down: Sell SL of 0.05% PT of 0.10% Breakout 3-4
// EV : 1.36%	 Win: 53.12%, Avg Win: 7.81%, Avg Loss: -5.96%, total: 337, Industry Cycle Up: Buy hold for 10 bars Breakout 4-5
// EV : 1.35%	 Win: 18.18%, Avg Win: 29.06%, Avg Loss: -4.81%, total: 9001, Spy Long Term Up: Buy and use signal open as stop All
// EV : 1.35%	 Win: 58.75%, Avg Win: 15.02%, Avg Loss: -18.14%, total: 160, Industry Cycle Up: Sell hold for 60 bars Breakout 4x+ & Price Angle <= -20 degrees
// EV : 1.34%	 Win: 53.71%, Avg Win: 13.49%, Avg Loss: -12.74%, total: 1348, Spy Long Term Down: Buy hold for 30 bars Breakout 2-3
// EV : 1.33%	 Win: 17.02%, Avg Win: 26.92%, Avg Loss: -3.91%, total: 423, Spy Long Term Up: Buy and use signal close as stop Breakout 5+
// EV : 1.33%	 Win: 26.01%, Avg Win: 29.80%, Avg Loss: -8.68%, total: 223, Spy Long Term Down: Sell hold for 60 bars SL of 0.05% Breakout 5+
// EV : 1.33%	 Win: 52.39%, Avg Win: 16.97%, Avg Loss: -15.89%, total: 3327, Spy Short Term Up: Buy hold for 60 bars Negative Price Slope
// EV : 1.33%	 Win: 43.08%, Avg Win: 51.22%, Avg Loss: -36.43%, total: 65, None: Buy Breakout 4x+ & Price Angle <= -20 degrees
// EV : 1.32%	 Win: 18.37%, Avg Win: 39.08%, Avg Loss: -7.17%, total: 147, Spy Short Term Up: Buy SL of 0.05% Breakout 4-5
// EV : 1.32%	 Win: 43.49%, Avg Win: 14.00%, Avg Loss: -8.43%, total: 5544, Industry Cycle Up: Buy and use trailing stop, SL of 0.1% Negative Price Slope
// EV : 1.31%	 Win: 38.91%, Avg Win: 15.47%, Avg Loss: -7.71%, total: 460, Spy Short Term Up: Buy hold for 30 bars SL of 0.05% Breakout 5+
// EV : 1.31%	 Win: 51.45%, Avg Win: 15.09%, Avg Loss: -13.30%, total: 1761, Industry Cycle Up: Buy hold for 60 bars Breakout 2-3
// EV : 1.30%	 Win: 39.16%, Avg Win: 17.45%, Avg Loss: -9.09%, total: 1425, Industry Cycle Down: Buy and use trailing stop, SL of 0.1% Breakout 2-3
// EV : 1.30%	 Win: 13.92%, Avg Win: 43.49%, Avg Loss: -5.53%, total: 3585, None: Buy and use signal open as stop Breakout 2-3
// EV : 1.30%	 Win: 39.75%, Avg Win: 13.21%, Avg Loss: -6.57%, total: 7954, Spy Long Term Up: Buy hold for 30 bars SL of 0.05% Negative Price Slope
// EV : 1.29%	 Win: 41.67%, Avg Win: 15.21%, Avg Loss: -8.65%, total: 180, Price above 30: Sell and use trailing stop, SL of 0.1% Breakout 4-5
// EV : 1.29%	 Win: 38.58%, Avg Win: 14.16%, Avg Loss: -6.80%, total: 2092, Spy Short Term Down: Buy hold for 30 bars SL of 0.05% Breakout 2-3
// EV : 1.28%	 Win: 37.57%, Avg Win: 19.65%, Avg Loss: -9.77%, total: 181, Spy Short Term Down: Buy and use trailing stop, SL of 0.1% Breakout 4-5
// EV : 1.28%	 Win: 41.72%, Avg Win: 14.83%, Avg Loss: -8.42%, total: 6030, Price above 30: Buy and use trailing stop, SL of 0.1% Negative Price Slope
// EV : 1.28%	 Win: 38.06%, Avg Win: 14.49%, Avg Loss: -6.84%, total: 7701, Spy Short Term Down: Buy hold for 30 bars SL of 0.05% Negative Price Slope
// EV : 1.27%	 Win: 19.48%, Avg Win: 59.03%, Avg Loss: -12.70%, total: 991, Spy Short Term Down: Buy SL of 0.10% Positive Price Slope
// EV : 1.27%	 Win: 54.55%, Avg Win: 34.08%, Avg Loss: -38.11%, total: 33, Spy Long Term Up: Buy Breakout 3-4
// EV : 1.27%	 Win: 52.37%, Avg Win: 11.93%, Avg Loss: -10.46%, total: 6066, Price above 30: Buy hold for 30 bars Negative Price Slope
// EV : 1.27%	 Win: 18.27%, Avg Win: 38.42%, Avg Loss: -7.04%, total: 104, Spy Short Term Down: Sell SL of 0.05% Breakout 4-5
// EV : 1.27%	 Win: 40.92%, Avg Win: 12.61%, Avg Loss: -6.59%, total: 6501, Industry Cycle Up: Buy hold for 30 bars SL of 0.05% Negative Price Slope
// EV : 1.26%	 Win: 17.27%, Avg Win: 20.99%, Avg Loss: -2.86%, total: 1587, Industry Cycle Down: Buy and use signal close as stop Breakout 2-3
// EV : 1.26%	 Win: 51.33%, Avg Win: 15.67%, Avg Loss: -13.95%, total: 8809, Industry Cycle Up: Buy hold for 60 bars All
// EV : 1.25%	 Win: 33.72%, Avg Win: 17.50%, Avg Loss: -7.01%, total: 6012, Industry Cycle Up: Buy hold for 60 bars SL of 0.05% Negative Price Slope
// EV : 1.24%	 Win: 16.84%, Avg Win: 18.75%, Avg Loss: -2.30%, total: 2221, Price above 30: Buy and use signal close as stop Breakout 2-3
// EV : 1.24%	 Win: 51.53%, Avg Win: 13.38%, Avg Loss: -11.66%, total: 12415, None: Buy hold for 30 bars Negative Price Slope
// EV : 1.24%	 Win: 19.31%, Avg Win: 17.93%, Avg Loss: -2.75%, total: 5744, Industry Cycle Up: Buy and use signal close as stop Negative Price Slope
// EV : 1.24%	 Win: 25.49%, Avg Win: 42.15%, Avg Loss: -12.76%, total: 102, Spy Long Term Up: Buy SL of 0.10% Breakout 4-5
// EV : 1.24%	 Win: 16.22%, Avg Win: 46.07%, Avg Loss: -7.44%, total: 185, Spy Short Term Up: Buy and use signal open as stop Breakout 4-5
// EV : 1.23%	 Win: 15.83%, Avg Win: 35.15%, Avg Loss: -5.15%, total: 8826, Industry Cycle Up: Buy and use signal open as stop All
// EV : 1.23%	 Win: 16.42%, Avg Win: 35.70%, Avg Loss: -5.55%, total: 1663, Industry Cycle Up: Buy and use signal open as stop Breakout 2-3
// EV : 1.21%	 Win: 35.99%, Avg Win: 15.69%, Avg Loss: -6.92%, total: 5660, Industry Cycle Down: Buy hold for 30 bars SL of 0.05% Negative Price Slope
// EV : 1.20%	 Win: 13.25%, Avg Win: 57.37%, Avg Loss: -7.37%, total: 317, None: Buy SL of 0.05% Breakout 4-5
// ...
// EV : -4.54%	 Win: 17.34%, Avg Win: 31.92%, Avg Loss: -12.19%, total: 3644, Spy Short Term Down: Sell SL of 0.10% All
// EV : -4.56%	 Win: 39.08%, Avg Win: 12.83%, Avg Loss: -15.71%, total: 87, Price above 30: Buy hold for 60 bars Breakout 4x+ & Price Angle <= -20 degrees
// EV : -4.58%	 Win: 16.94%, Avg Win: 35.42%, Avg Loss: -12.74%, total: 1913, Spy Long Term Down: Sell SL of 0.10% Positive Price Slope
// EV : -4.59%	 Win: 20.76%, Avg Win: 23.46%, Avg Loss: -11.95%, total: 3993, Spy Short Term Up: Sell SL of 0.10% Positive Price Slope
// EV : -4.60%	 Win: 20.84%, Avg Win: 20.74%, Avg Loss: -11.27%, total: 950, Spy Long Term Up: Sell SL of 0.10% Breakout 2-3
// EV : -4.63%	 Win: 21.28%, Avg Win: 21.91%, Avg Loss: -11.80%, total: 3458, Industry Cycle Up: Sell SL of 0.10% Positive Price Slope
// EV : -4.67%	 Win: 52.17%, Avg Win: 35.81%, Avg Loss: -48.84%, total: 46, Spy Long Term Down: Sell Breakout 3-4
// EV : -4.74%	 Win: 22.63%, Avg Win: 21.39%, Avg Loss: -12.39%, total: 274, Spy Long Term Up: Sell SL of 0.10% Breakout 3-4
// EV : -4.75%	 Win: 27.68%, Avg Win: 37.28%, Avg Loss: -20.84%, total: 1539, Price above 30: Sell SL of 0.20% Negative Price Slope
// EV : -4.77%	 Win: 22.27%, Avg Win: 20.87%, Avg Loss: -12.11%, total: 1630, Spy Long Term Up: Sell SL of 0.10% Negative Price Slope
// EV : -4.78%	 Win: 22.58%, Avg Win: 12.30%, Avg Loss: -9.77%, total: 62, Spy Short Term Down: Buy hold for 60 bars SL of 0.05% Breakout 4x+ & Price Angle <= -20 degrees
// EV : -4.80%	 Win: 29.29%, Avg Win: 29.49%, Avg Loss: -19.01%, total: 99, Spy Short Term Up: Sell SL of 0.20% Breakout 4x+ & Price Angle <= -20 degrees
// EV : -4.81%	 Win: 28.95%, Avg Win: 34.78%, Avg Loss: -20.94%, total: 7300, None: Sell SL of 0.20% All
// EV : -4.86%	 Win: 64.71%, Avg Win: 35.63%, Avg Loss: -79.10%, total: 17, Spy Short Term Down: Sell Breakout 4x+ & Price Angle <= -20 degrees
// EV : -4.90%	 Win: 21.51%, Avg Win: 20.08%, Avg Loss: -11.74%, total: 5031, Spy Long Term Up: Sell SL of 0.10% All
// EV : -4.94%	 Win: 38.75%, Avg Win: 15.15%, Avg Loss: -17.64%, total: 3249, Industry Cycle Down: Sell hold for 60 bars Negative Price Slope
// EV : -4.96%	 Win: 21.14%, Avg Win: 19.67%, Avg Loss: -11.57%, total: 3401, Spy Long Term Up: Sell SL of 0.10% Positive Price Slope
// EV : -4.99%	 Win: 41.18%, Avg Win: 12.16%, Avg Loss: -17.00%, total: 51, Spy Short Term Down: Buy hold for 60 bars Breakout 4x+ & Price Angle <= -20 degrees
// EV : -5.01%	 Win: 29.16%, Avg Win: 32.11%, Avg Loss: -20.29%, total: 4310, None: Sell SL of 0.20% Positive Price Slope
// EV : -5.01%	 Win: 16.86%, Avg Win: 30.61%, Avg Loss: -12.24%, total: 1613, Spy Short Term Down: Sell SL of 0.10% Positive Price Slope
// EV : -5.02%	 Win: 20.83%, Avg Win: 70.04%, Avg Loss: -24.77%, total: 24, Spy Short Term Down: Buy SL of 0.20% Breakout 4x+ & Price Angle <= -20 degrees
// EV : -5.04%	 Win: 29.89%, Avg Win: 25.72%, Avg Loss: -18.16%, total: 87, Spy Long Term Up: Sell SL of 0.20% Breakout 4x+ & Price Angle <= -20 degrees
// EV : -5.10%	 Win: 24.69%, Avg Win: 13.44%, Avg Loss: -11.17%, total: 81, Industry Cycle Down: Buy and use trailing stop, SL of 0.1% Breakout 4x+ & Price Angle <= -20 degrees
// EV : -5.20%	 Win: 30.00%, Avg Win: 35.27%, Avg Loss: -22.55%, total: 110, Industry Cycle Down: Sell SL of 0.20% Breakout 3-4
// EV : -5.31%	 Win: 11.86%, Avg Win: 23.58%, Avg Loss: -9.20%, total: 59, Spy Short Term Down: Sell SL of 0.05% Breakout 4x+ & Price Angle <= -20 degrees
// EV : -5.33%	 Win: 18.18%, Avg Win: 35.52%, Avg Loss: -14.41%, total: 143, Industry Cycle Down: Buy SL of 0.10% Breakout 5+
// EV : -5.52%	 Win: 13.43%, Avg Win: 21.72%, Avg Loss: -9.75%, total: 67, Industry Cycle Down: Buy and use signal open as stop Breakout 4x+ & Price Angle <= -20 degrees
// EV : -5.52%	 Win: 23.21%, Avg Win: 51.22%, Avg Loss: -22.67%, total: 56, Spy Short Term Down: Buy SL of 0.20% Breakout 4-5
// EV : -5.52%	 Win: 18.90%, Avg Win: 75.04%, Avg Loss: -24.29%, total: 127, Spy Short Term Down: Buy SL of 0.20% Breakout 5+
// EV : -5.63%	 Win: 31.07%, Avg Win: 27.81%, Avg Loss: -20.70%, total: 177, Industry Cycle Up: Sell SL of 0.20% Breakout 3-4
// EV : -5.63%	 Win: 7.01%, Avg Win: 64.82%, Avg Loss: -10.94%, total: 214, Spy Long Term Down: Buy and use signal open as stop Breakout 5+
// EV : -5.84%	 Win: 53.85%, Avg Win: 25.58%, Avg Loss: -42.50%, total: 13, Spy Short Term Up: Buy Breakout 4-5
// EV : -5.93%	 Win: 15.20%, Avg Win: 29.71%, Avg Loss: -12.32%, total: 1704, Industry Cycle Down: Sell SL of 0.10% Positive Price Slope
// EV : -6.02%	 Win: 14.57%, Avg Win: 31.48%, Avg Loss: -12.41%, total: 3048, Industry Cycle Down: Sell SL of 0.10% All
// EV : -6.09%	 Win: 30.92%, Avg Win: 22.96%, Avg Loss: -19.09%, total: 608, Industry Cycle Up: Sell SL of 0.20% Breakout 2-3
// EV : -6.13%	 Win: 13.76%, Avg Win: 33.95%, Avg Loss: -12.53%, total: 1344, Industry Cycle Down: Sell SL of 0.10% Negative Price Slope
// EV : -6.18%	 Win: 27.29%, Avg Win: 31.59%, Avg Loss: -20.35%, total: 1059, Spy Short Term Down: Sell SL of 0.20% Positive Price Slope
// EV : -6.22%	 Win: 40.00%, Avg Win: 29.09%, Avg Loss: -29.75%, total: 25, Spy Short Term Up: Sell Breakout 4x+ & Price Angle <= -20 degrees
// EV : -6.32%	 Win: 30.43%, Avg Win: 33.53%, Avg Loss: -23.76%, total: 46, Industry Cycle Down: Buy SL of 0.20% Breakout 4-5
// EV : -6.34%	 Win: 33.33%, Avg Win: 64.70%, Avg Loss: -41.86%, total: 21, Price above 30: Buy Breakout 4x+ & Price Angle <= -20 degrees
// EV : -6.35%	 Win: 26.68%, Avg Win: 32.37%, Avg Loss: -20.44%, total: 476, Spy Short Term Down: Sell SL of 0.20% Breakout 2-3
// EV : -6.40%	 Win: 12.97%, Avg Win: 32.41%, Avg Loss: -12.18%, total: 586, Industry Cycle Down: Sell SL of 0.10% Breakout 2-3
// EV : -6.44%	 Win: 5.56%, Avg Win: 123.26%, Avg Loss: -14.07%, total: 36, Spy Short Term Down: Buy SL of 0.10% Breakout 4x+ & Price Angle <= -20 degrees
// EV : -6.48%	 Win: 55.88%, Avg Win: 33.37%, Avg Loss: -56.95%, total: 34, Industry Cycle Down: Sell Breakout 3-4
// EV : -6.55%	 Win: 7.89%, Avg Win: 84.06%, Avg Loss: -14.31%, total: 38, Price above 30: Buy SL of 0.10% Breakout 4x+ & Price Angle <= -20 degrees
// EV : -6.76%	 Win: 29.43%, Avg Win: 22.73%, Avg Loss: -19.06%, total: 2178, Industry Cycle Up: Sell SL of 0.20% Positive Price Slope
// EV : -6.89%	 Win: 25.96%, Avg Win: 32.57%, Avg Loss: -20.72%, total: 2473, Spy Short Term Down: Sell SL of 0.20% All
// EV : -6.97%	 Win: 29.51%, Avg Win: 24.73%, Avg Loss: -20.24%, total: 610, Spy Short Term Up: Sell SL of 0.20% Breakout 2-3
// EV : -7.00%	 Win: 30.30%, Avg Win: 32.72%, Avg Loss: -24.27%, total: 33, Spy Short Term Down: Sell SL of 0.20% Breakout 4x+ & Price Angle <= -20 degrees
// EV : -7.03%	 Win: 29.04%, Avg Win: 23.65%, Avg Loss: -19.59%, total: 3209, Industry Cycle Up: Sell SL of 0.20% All
// EV : -7.13%	 Win: 28.64%, Avg Win: 21.16%, Avg Loss: -18.49%, total: 2151, Spy Long Term Up: Sell SL of 0.20% Positive Price Slope
// EV : -7.16%	 Win: 28.73%, Avg Win: 23.21%, Avg Loss: -19.40%, total: 181, Spy Long Term Up: Sell SL of 0.20% Breakout 3-4
// EV : -7.18%	 Win: 17.65%, Avg Win: 23.08%, Avg Loss: -13.66%, total: 51, Spy Short Term Down: Sell SL of 0.10% Breakout 4x+ & Price Angle <= -20 degrees
// EV : -7.19%	 Win: 9.43%, Avg Win: 15.49%, Avg Loss: -9.55%, total: 53, Industry Cycle Down: Buy SL of 0.05% Breakout 4x+ & Price Angle <= -20 degrees
// EV : -7.27%	 Win: 32.59%, Avg Win: 33.20%, Avg Loss: -26.84%, total: 135, Spy Short Term Up: Sell SL of 0.20% Breakout 5+
// EV : -7.29%	 Win: 30.57%, Avg Win: 25.63%, Avg Loss: -21.78%, total: 193, Spy Short Term Up: Sell SL of 0.20% Breakout 3-4
// EV : -7.32%	 Win: 29.11%, Avg Win: 21.55%, Avg Loss: -19.17%, total: 608, Spy Long Term Up: Sell SL of 0.20% Breakout 2-3
// EV : -7.37%	 Win: 28.43%, Avg Win: 23.57%, Avg Loss: -19.65%, total: 2540, Spy Short Term Up: Sell SL of 0.20% Positive Price Slope
// EV : -7.42%	 Win: 24.96%, Avg Win: 33.38%, Avg Loss: -20.99%, total: 1414, Spy Short Term Down: Sell SL of 0.20% Negative Price Slope
// EV : -7.46%	 Win: 28.00%, Avg Win: 21.69%, Avg Loss: -18.80%, total: 3232, Spy Long Term Up: Sell SL of 0.20% All
// EV : -7.48%	 Win: 28.24%, Avg Win: 25.05%, Avg Loss: -20.28%, total: 3414, Spy Short Term Up: Sell SL of 0.20% All
// EV : -7.49%	 Win: 26.23%, Avg Win: 32.63%, Avg Loss: -21.75%, total: 1239, Spy Long Term Down: Sell SL of 0.20% Positive Price Slope
// EV : -7.60%	 Win: 28.23%, Avg Win: 25.67%, Avg Loss: -20.69%, total: 1031, Industry Cycle Up: Sell SL of 0.20% Negative Price Slope
// EV : -7.67%	 Win: 27.03%, Avg Win: 36.51%, Avg Loss: -24.03%, total: 37, Spy Long Term Down: Sell SL of 0.20% Breakout 4x+ & Price Angle <= -20 degrees
// EV : -7.73%	 Win: 26.25%, Avg Win: 24.65%, Avg Loss: -19.26%, total: 80, Industry Cycle Up: Sell SL of 0.20% Breakout 4x+ & Price Angle <= -20 degrees
// EV : -7.81%	 Win: 27.69%, Avg Win: 29.47%, Avg Loss: -22.08%, total: 874, Spy Short Term Up: Sell SL of 0.20% Negative Price Slope
// EV : -7.97%	 Win: 24.94%, Avg Win: 32.96%, Avg Loss: -21.57%, total: 405, Spy Long Term Down: Sell SL of 0.20% Breakout 2-3
// EV : -7.98%	 Win: 17.72%, Avg Win: 61.85%, Avg Loss: -23.02%, total: 79, Price above 30: Buy SL of 0.20% Breakout 5+
// EV : -8.03%	 Win: 46.67%, Avg Win: 18.27%, Avg Loss: -31.05%, total: 15, Industry Cycle Down: Buy Breakout 4x+ & Price Angle <= -20 degrees
// EV : -8.06%	 Win: 21.00%, Avg Win: 55.04%, Avg Loss: -24.84%, total: 100, Industry Cycle Down: Buy SL of 0.20% Breakout 5+
// EV : -8.12%	 Win: 26.73%, Avg Win: 22.81%, Avg Loss: -19.41%, total: 1081, Spy Long Term Up: Sell SL of 0.20% Negative Price Slope
// EV : -8.25%	 Win: 34.00%, Avg Win: 21.38%, Avg Loss: -23.51%, total: 150, Spy Long Term Down: Buy hold for 60 bars Breakout 5+
// EV : -8.28%	 Win: 24.63%, Avg Win: 34.69%, Avg Loss: -22.32%, total: 2209, Spy Long Term Down: Sell SL of 0.20% All
// EV : -8.28%	 Win: 45.24%, Avg Win: 23.66%, Avg Loss: -34.67%, total: 42, Spy Long Term Up: Buy Breakout 5+
// EV : -8.30%	 Win: 33.33%, Avg Win: 40.51%, Avg Loss: -32.70%, total: 18, Industry Cycle Down: Sell Breakout 4-5
// EV : -8.38%	 Win: 30.33%, Avg Win: 32.46%, Avg Loss: -26.16%, total: 122, Industry Cycle Up: Sell SL of 0.20% Breakout 5+
// EV : -8.56%	 Win: 43.64%, Avg Win: 43.34%, Avg Loss: -48.74%, total: 802, Price above 30: Sell Positive Price Slope
// EV : -8.88%	 Win: 26.83%, Avg Win: 88.69%, Avg Loss: -44.66%, total: 41, Spy Short Term Down: Buy Breakout 5+
// EV : -8.95%	 Win: 23.56%, Avg Win: 29.38%, Avg Loss: -20.76%, total: 1108, Industry Cycle Down: Sell SL of 0.20% Positive Price Slope
// EV : -9.28%	 Win: 22.58%, Avg Win: 37.76%, Avg Loss: -23.00%, total: 970, Spy Long Term Down: Sell SL of 0.20% Negative Price Slope
// EV : -9.50%	 Win: 22.31%, Avg Win: 31.05%, Avg Loss: -21.14%, total: 2066, Industry Cycle Down: Sell SL of 0.20% All
// EV : -10.01%	 Win: 40.91%, Avg Win: 40.59%, Avg Loss: -45.03%, total: 22, Spy Short Term Down: Sell Breakout 4-5
// EV : -10.11%	 Win: 56.25%, Avg Win: 43.63%, Avg Loss: -79.21%, total: 48, Spy Short Term Down: Sell Breakout 3-4
// EV : -10.12%	 Win: 20.88%, Avg Win: 33.22%, Avg Loss: -21.56%, total: 958, Industry Cycle Down: Sell SL of 0.20% Negative Price Slope
// EV : -10.60%	 Win: 20.94%, Avg Win: 30.53%, Avg Loss: -21.49%, total: 382, Industry Cycle Down: Sell SL of 0.20% Breakout 2-3
// EV : -10.81%	 Win: 16.67%, Avg Win: 48.51%, Avg Loss: -22.67%, total: 48, Spy Long Term Down: Buy SL of 0.20% Breakout 4-5
// EV : -11.19%	 Win: 42.11%, Avg Win: 47.77%, Avg Loss: -54.07%, total: 19, Spy Long Term Down: Sell Breakout 4-5
// EV : -11.21%	 Win: 36.03%, Avg Win: 52.55%, Avg Loss: -47.12%, total: 136, None: Buy Breakout 5+
// EV : -11.29%	 Win: 30.00%, Avg Win: 22.29%, Avg Loss: -25.69%, total: 30, Industry Cycle Down: Buy SL of 0.20% Breakout 4x+ & Price Angle <= -20 degrees
// EV : -11.82%	 Win: 45.70%, Avg Win: 40.17%, Avg Loss: -55.57%, total: 1580, None: Sell Positive Price Slope
// EV : -12.03%	 Win: 35.45%, Avg Win: 32.55%, Avg Loss: -36.51%, total: 409, Spy Long Term Up: Sell Positive Price Slope
// EV : -12.37%	 Win: 11.90%, Avg Win: 13.36%, Avg Loss: -15.84%, total: 42, Industry Cycle Down: Buy SL of 0.10% Breakout 4x+ & Price Angle <= -20 degrees
// EV : -13.05%	 Win: 17.07%, Avg Win: 37.31%, Avg Loss: -23.42%, total: 41, Price above 30: Buy SL of 0.20% Breakout 4-5
// EV : -14.02%	 Win: 43.18%, Avg Win: 43.74%, Avg Loss: -57.90%, total: 1649, Price above 30: Sell All
// EV : -14.14%	 Win: 46.53%, Avg Win: 41.79%, Avg Loss: -62.81%, total: 3269, None: Sell All
// EV : -14.97%	 Win: 34.31%, Avg Win: 32.56%, Avg Loss: -39.80%, total: 717, Spy Long Term Up: Sell All
// EV : -15.07%	 Win: 25.81%, Avg Win: 56.54%, Avg Loss: -39.97%, total: 31, Industry Cycle Down: Buy Breakout 5+
// EV : -15.72%	 Win: 27.50%, Avg Win: 81.61%, Avg Loss: -52.64%, total: 40, Price above 30: Buy Breakout 5+
// EV : -16.31%	 Win: 47.31%, Avg Win: 43.25%, Avg Loss: -69.79%, total: 1689, None: Sell Negative Price Slope
// EV : -16.37%	 Win: 42.33%, Avg Win: 33.84%, Avg Loss: -53.22%, total: 378, Spy Short Term Down: Sell Positive Price Slope
// EV : -17.22%	 Win: 38.10%, Avg Win: 33.23%, Avg Loss: -48.27%, total: 21, Industry Cycle Up: Sell Breakout 4x+ & Price Angle <= -20 degrees
// EV : -17.65%	 Win: 48.65%, Avg Win: 42.44%, Avg Loss: -74.58%, total: 592, None: Sell Breakout 2-3
// EV : -18.89%	 Win: 32.79%, Avg Win: 32.59%, Avg Loss: -44.00%, total: 308, Spy Long Term Up: Sell Negative Price Slope
// EV : -19.18%	 Win: 46.85%, Avg Win: 44.68%, Avg Loss: -75.48%, total: 286, Price above 30: Sell Breakout 2-3
// EV : -19.19%	 Win: 42.74%, Avg Win: 44.12%, Avg Loss: -66.44%, total: 847, Price above 30: Sell Negative Price Slope
// EV : -20.44%	 Win: 41.99%, Avg Win: 33.79%, Avg Loss: -59.69%, total: 181, Industry Cycle Up: Sell Breakout 2-3
// EV : -20.65%	 Win: 36.09%, Avg Win: 31.02%, Avg Loss: -49.82%, total: 557, Industry Cycle Up: Sell Positive Price Slope
// EV : -21.18%	 Win: 35.88%, Avg Win: 30.67%, Avg Loss: -50.20%, total: 680, Spy Short Term Up: Sell Positive Price Slope
// EV : -21.32%	 Win: 35.95%, Avg Win: 40.18%, Avg Loss: -55.84%, total: 153, Spy Long Term Up: Sell Breakout 2-3
// EV : -21.79%	 Win: 40.89%, Avg Win: 34.10%, Avg Loss: -60.44%, total: 203, Spy Short Term Down: Sell Breakout 2-3
// EV : -22.39%	 Win: 35.78%, Avg Win: 32.89%, Avg Loss: -53.19%, total: 1048, Spy Short Term Up: Sell All
// EV : -22.59%	 Win: 50.00%, Avg Win: 27.72%, Avg Loss: -72.90%, total: 14, Spy Long Term Down: Sell Breakout 4x+ & Price Angle <= -20 degrees
// EV : -23.50%	 Win: 34.57%, Avg Win: 31.21%, Avg Loss: -52.40%, total: 324, Industry Cycle Down: Sell Positive Price Slope
// EV : -23.78%	 Win: 39.08%, Avg Win: 35.21%, Avg Loss: -61.61%, total: 1108, Spy Short Term Down: Sell All
// EV : -24.29%	 Win: 35.73%, Avg Win: 31.95%, Avg Loss: -55.55%, total: 960, Industry Cycle Up: Sell All
// EV : -24.62%	 Win: 35.60%, Avg Win: 37.02%, Avg Loss: -58.68%, total: 368, Spy Short Term Up: Sell Negative Price Slope
// EV : -26.38%	 Win: 31.82%, Avg Win: 43.11%, Avg Loss: -58.82%, total: 22, Price above 30: Buy Breakout 4-5
// EV : -27.61%	 Win: 37.40%, Avg Win: 36.01%, Avg Loss: -65.61%, total: 730, Spy Short Term Down: Sell Negative Price Slope
// EV : -28.67%	 Win: 37.31%, Avg Win: 37.68%, Avg Loss: -68.16%, total: 193, Spy Short Term Up: Sell Breakout 2-3
// EV : -29.32%	 Win: 35.24%, Avg Win: 33.26%, Avg Loss: -63.36%, total: 403, Industry Cycle Up: Sell Negative Price Slope
// EV : -29.42%	 Win: 32.26%, Avg Win: 32.42%, Avg Loss: -58.87%, total: 806, Industry Cycle Down: Sell All
// EV : -29.56%	 Win: 36.12%, Avg Win: 30.14%, Avg Loss: -63.32%, total: 515, Spy Long Term Down: Sell Positive Price Slope
// EV : -33.40%	 Win: 30.71%, Avg Win: 33.34%, Avg Loss: -62.97%, total: 482, Industry Cycle Down: Sell Negative Price Slope
// EV : -33.74%	 Win: 34.44%, Avg Win: 32.37%, Avg Loss: -68.48%, total: 1141, Spy Long Term Down: Sell All
// EV : -37.17%	 Win: 33.07%, Avg Win: 34.38%, Avg Loss: -72.53%, total: 626, Spy Long Term Down: Sell Negative Price Slope
// EV : -37.23%	 Win: 33.85%, Avg Win: 31.47%, Avg Loss: -72.37%, total: 195, Spy Long Term Down: Sell Breakout 2-3
// EV : -41.29%	 Win: 24.84%, Avg Win: 41.89%, Avg Loss: -68.77%, total: 153, Industry Cycle Down: Sell Breakout 2-3

// %%
// sort by ev and print the heck out of it
let sellOutcomes = load "Sell.csv"

let tradesOfInterest = sellOutcomes.Rows |> Seq.filter (fun r -> r.BreakoutVolumeRate >= 5m)

let sumarryOf5XSell = summarizeRecords "5X Sell" tradesOfInterest

sumarryOf5XSell.Describe()

sumarryOf5XSell.outcomes
|> Seq.iter(fun o ->
    let date = System.DateTime.Parse(o.Date)
    let dateMinus30 = date.AddDays(-30)
    let newDate = dateMinus30.ToString("yyyy-MM-dd")
    $"{o.Ticker}, {o.Date} https://localhost:44406/stocks/{o.Ticker}/analysis?startDate={newDate}" |> outputToConsole
)
// Out:
// ASTL, 2021-05-25 https://localhost:44406/stocks/ASTL/analysis?startDate=2021-04-25
// CONN, 2021-06-03 https://localhost:44406/stocks/CONN/analysis?startDate=2021-05-04
// IRMD, 2021-06-03 https://localhost:44406/stocks/IRMD/analysis?startDate=2021-05-04
// BBAI, 2021-06-04 https://localhost:44406/stocks/BBAI/analysis?startDate=2021-05-05
// NAPA, 2021-06-08 https://localhost:44406/stocks/NAPA/analysis?startDate=2021-05-09
// PNRG, 2021-06-25 https://localhost:44406/stocks/PNRG/analysis?startDate=2021-05-26
// VEL, 2021-06-25 https://localhost:44406/stocks/VEL/analysis?startDate=2021-05-26
// FRGE, 2021-06-28 https://localhost:44406/stocks/FRGE/analysis?startDate=2021-05-29
// PMTS, 2021-06-30 https://localhost:44406/stocks/PMTS/analysis?startDate=2021-05-31
// AADI, 2021-07-08 https://localhost:44406/stocks/AADI/analysis?startDate=2021-06-08
// TBLT, 2021-07-08 https://localhost:44406/stocks/TBLT/analysis?startDate=2021-06-08
// DLA, 2021-07-15 https://localhost:44406/stocks/DLA/analysis?startDate=2021-06-15
// IPWR, 2021-07-20 https://localhost:44406/stocks/IPWR/analysis?startDate=2021-06-20
// ARVN, 2021-07-22 https://localhost:44406/stocks/ARVN/analysis?startDate=2021-06-22
// KE, 2021-07-23 https://localhost:44406/stocks/KE/analysis?startDate=2021-06-23
// ARCC, 2021-07-29 https://localhost:44406/stocks/ARCC/analysis?startDate=2021-06-29
// OWL, 2021-08-03 https://localhost:44406/stocks/OWL/analysis?startDate=2021-07-04
// ATOM, 2021-08-04 https://localhost:44406/stocks/ATOM/analysis?startDate=2021-07-05
// VICI, 2021-08-04 https://localhost:44406/stocks/VICI/analysis?startDate=2021-07-05
// DDOG, 2021-08-05 https://localhost:44406/stocks/DDOG/analysis?startDate=2021-07-06
// HNNA, 2021-08-05 https://localhost:44406/stocks/HNNA/analysis?startDate=2021-07-06
// NVRO, 2021-08-05 https://localhost:44406/stocks/NVRO/analysis?startDate=2021-07-06
// RYI, 2021-08-05 https://localhost:44406/stocks/RYI/analysis?startDate=2021-07-06
// CRVO, 2024-02-08 https://localhost:44406/stocks/CRVO/analysis?startDate=2024-01-09
// SRZN, 2024-02-13 https://localhost:44406/stocks/SRZN/analysis?startDate=2024-01-14
// EGIO, 2024-02-26 https://localhost:44406/stocks/EGIO/analysis?startDate=2024-01-27
// APEI, 2024-03-06 https://localhost:44406/stocks/APEI/analysis?startDate=2024-02-05
// SDHC, 2024-03-15 https://localhost:44406/stocks/SDHC/analysis?startDate=2024-02-14
// ADSE, 2024-03-28 https://localhost:44406/stocks/ADSE/analysis?startDate=2024-02-27
// VTSI, 2024-04-02 https://localhost:44406/stocks/VTSI/analysis?startDate=2024-03-03
// VBNK, 2024-04-05 https://localhost:44406/stocks/VBNK/analysis?startDate=2024-03-06
// ABL, 2024-04-08 https://localhost:44406/stocks/ABL/analysis?startDate=2024-03-09
// CNTA, 2024-04-24 https://localhost:44406/stocks/CNTA/analysis?startDate=2024-03-25
// DPSI, 2024-05-01 https://localhost:44406/stocks/DPSI/analysis?startDate=2024-04-01
// AXIL, 2024-05-10 https://localhost:44406/stocks/AXIL/analysis?startDate=2024-04-10

// %%
#r "nuget: Microsoft.DotNet.Interactive.Formatting"
open Microsoft.DotNet.Interactive.Formatting

// Enable HTML output
Formatter.SetPreferredMimeTypesFor(typeof<obj>, "text/html")

// Function to create a clickable link
let createLink (text: string) (url: string) =
    sprintf "<a href='%s' target='_blank'>%s</a>" url text

// Generate some links
let links = [
    createLink "F# Documentation" "https://docs.microsoft.com/en-us/dotnet/fsharp/"
    createLink "F# for Fun and Profit" "https://fsharpforfunandprofit.com/"
    createLink "F# Software Foundation" "https://fsharp.org/"
]

// Display the links
links |> String.concat "<br/>" |> display
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>microsoft.dotnet.interactive.formatting, 1.0.0-beta.24229.4</span></li></ul></div></div>
// <a href='https://docs.microsoft.com/en-us/dotnet/fsharp/' target='_blank'>F# Documentation</a><br/><a href='https://fsharpforfunandprofit.com/' target='_blank'>F# for Fun and Profit</a><br/><a href='https://fsharp.org/' target='_blank'>F# Software Foundation</a>

// %%
#r "nuget: XPlot.Plotly"

open XPlot.Plotly

let csv = load "Buy.csv"

let rowsToUse = 
    csv.Rows
    |> above30PriceFilter
    |> Seq.filter(fun r -> r.BreakoutVolumeRate >= 4m)

let xLabel = "Breakout Vol Rate"
let x = rowsToUse |> Seq.map (fun s -> s.BreakoutVolumeRate)
let gains = rowsToUse |> Seq.map (fun s -> s.PercentGain * 100m)

// Create a scatter plot
let trace =
    Scatter(
        x = x,
        y = gains,
        mode = "markers",
        marker = Marker(size = 10)
    )

// Set up the layout
let layout =
    Layout(
        title = $"{xLabel} vs Gains",
        xaxis = Xaxis(title = xLabel),
        yaxis = Yaxis(title = "Gains")
    )

// Create and display the chart
[trace]
|> Chart.Plot
|> Chart.WithLayout layout
|> Chart.Show

// now histogram of gains
let histogramTrace =
    Histogram(
        x = gains,
        name = "Gains Distribution",
        marker = Marker(color = "rgba(255, 100, 102, 0.7)")
    )

[histogramTrace]
|> Chart.Plot
|> Chart.Show
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>XPlot.Plotly, 4.1.0</span></li></ul></div></div>
